# %% [markdown]
# # How to use this notebook (recommended for non-CLI users)
#
# This notebook is designed for users who prefer working interactively rather than running command-line scripts.
#
# - Step 1: Ensure you have activated the `pyagri-notebooks` environment and installed the package in editable mode (`pip install -e .`). See the top cell for environment checks.
# - Step 2: Set the `PROJECT_ROOT` variable in the **Configuration** cell if you want to use an explicit absolute path; otherwise the notebook will use the current working directory. All other data paths (inputs and outputs) are relative to `PROJECT_ROOT`.
# - Step 3: In the **Configuration** cell, confirm `INPUT_TASKDATA` (list of TaskData folders), `LEDREBORG_OUT` and `HARVEST_GEOJSON` look correct.
# - Step 4 (recommended): Run the small **Per-input API** cell for the specific input(s) you want to process — this calls the library functions directly and shows concise results inline.
# - Step 5: Use the **Advanced: Batch run** cell only if you want to process multiple inputs in one go (this runs subprocesses and is better for batch jobs, not interactive exploration).
#
# If a GeoJSON or CSV already exists, the notebook will append features or rows rather than overwrite, so you can safely run the same input multiple times for incremental exports.
#
# Tip: to quickly set `PROJECT_ROOT` to the workspace root use:
#
# ```python
# PROJECT_ROOT = Path(r"C:/dev/agri_analysis").resolve()
# ```

# %%
# 01_Raw_read
# Friendly notebook that reproduces the CLI workflows:
#  - python -m pyagri.export data/TASKDATA_2 data/ledreborg_CSV
#  - python -m pyagri.geo data/TASKDATA data/harvest_fields_s.geojson

# NOTE: This notebook is intended to be run in the `pyagri-notebooks` environment
# (or another environment with the project installed in editable mode).
# Recommended quick setup (run in a shell once):
#   micromamba activate pyagri-notebooks
#   pip install -e .
#   pip install geopandas pandas

# Section 1: Quick environment check
import sys
from pathlib import Path
import logging

logger = logging.getLogger('01_Raw_read')
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
handler.setLevel(logging.INFO)
logger.addHandler(handler)

logger.info('Python executable: %s', sys.executable)
try:
    import pyagri
    logger.info('pyagri import OK')
except Exception as e:
    logger.warning('pyagri import failed: %s', e)
# Out:
# Python executable: /Users/holmes/micromamba/envs/pyagri-notebooks/bin/python
# pyagri import OK

# %%
# Configuration cell — set project root, inputs and outputs here
# Set the PROJECT_ROOT to the absolute path of the folder containing the data (the previous cell set it to the folder of the notebook)
# Example explicit override (uncomment and adjust if you run the notebook from a different working directory):
PROJECT_ROOT = Path.cwd().resolve().parent

# PROJECT_ROOT = Path(r"C:/dev/agri_analysis").resolve()

DATA_DIR = PROJECT_ROOT / 'data'

# You can specify more than one TaskData folder in INPUT_TASKDATA list. These are paths relative to PROJECT_ROOT.
INPUT_TASKDATA = [
    DATA_DIR / 'TASKDATA_2',  # example input folder 1
    DATA_DIR / 'TASKDATA',  # add more as needed
]

# CSV output directory (one dir used for all inputs; files for each task will be appended)
HARVESTER_POINTS_DIR = PROJECT_ROOT / 'data' / 'ledreborg_CSV'
HARVESTER_POINTS_DIR.mkdir(parents=True, exist_ok=True)

# GeoJSON output file for task polygons (appends features if file exists)
FIELD_POLYGONS_GEOJSON = PROJECT_ROOT / 'data' / 'harvest_fields_s.geojson'

# --- Set target projected CRS for area/overlap analysis ---
# Use EPSG:25832 (ETRS89 / UTM zone 32N) for Denmark
EPSG = '25832'  # Change as needed for your region


logger.info('Project root: %s', PROJECT_ROOT)
logger.info('Configured %d input folders: %s', len(INPUT_TASKDATA), [str(p) for p in INPUT_TASKDATA])
logger.info('CSV output dir: %s', HARVESTER_POINTS_DIR)
logger.info('GeoJSON output file: %s', FIELD_POLYGONS_GEOJSON)
logger.info('Target projected CRS EPSG: %s', EPSG)
# Out:
# Project root: /Users/holmes/local_dev/agri_analysis
# Configured 2 input folders: ['/Users/holmes/local_dev/agri_analysis/data/TASKDATA_2', '/Users/holmes/local_dev/agri_analysis/data/TASKDATA']
# CSV output dir: /Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV
# GeoJSON output file: /Users/holmes/local_dev/agri_analysis/data/harvest_fields_s.geojson
# Target projected CRS EPSG: 25832

# %% [markdown]
# ## Loding binary data
# The following cell loads the data form the XML and binary data and exports it to CSV and GeoJSON for futher analasis. If you alredy have converted the data and only want to validate the data skip the following cell

# %%
# Per-input API example 
try:
    from pyagri import export as export_mod
    from pyagri import geo as geo_mod
    for src in INPUT_TASKDATA:
        srcp = Path(src)
        if not srcp.exists():
            logger.warning('Skipping missing input: %s', srcp)
            continue
        logger.info('Exporting (API) for: %s', srcp)
        written = export_mod.export_taskdata(str(srcp), str(HARVESTER_POINTS_DIR))
        logger.info('Wrote CSV files: %s', written)

        logger.info('Extracting GeoJSON (API) for: %s', srcp)
        rc = geo_mod.extract_taskdata_to_geojson(str(srcp), str(FIELD_POLYGONS_GEOJSON))
        logger.info('Geo extraction returned: %s (%s)', rc, 'success' if rc == 0 else 'error')
except Exception as e:
    logger.exception('Per-input API example failed: %s', e)
# Out:
# Skipping missing input: /Users/holmes/local_dev/agri_analysis/data/TASKDATA_2
# Exporting (API) for: /Users/holmes/local_dev/agri_analysis/data/TASKDATA
# Wrote CSV files: ['/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/021-0_ Monica.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/021-0_ Monica.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/021-0_ Monica.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/022-0_ Lidia.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/022-0_ Lidia.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/022-0_ Lidia.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/022-0_ Lidia.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/016-2_ Stendyssegård Højre.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/016-2_ Stendyssegård Højre.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/011-0_ Akselbæk.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/011-0_ Akselbæk.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/011-0_ Akselbæk.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/B025-1_ Brak - C_T Syd.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/B025-1_ Brak - C_T Syd.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/023-2_ Veronica 2.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/023-2_ Veronica 2.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/023-2_ Veronica 2.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/040-0_ Holmegård syd.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/040-0_ Holmegård syd.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/040-0_ Holmegård syd.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/011-0_ Akselbæk.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/011-0_ Akselbæk.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/012-0_ Hulegaardsmark.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/012-0_ Hulegaardsmark.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/012-0_ Hulegaardsmark.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/015-0_ Hulemølle.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/015-0_ Hulemølle.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/015-0_ Hulemølle.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/035-0_ Bispegård mark.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/035-0_ Bispegård mark.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/035-0_ Bispegård mark.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/Import.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/014-0_ Dellingemølle.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/014-0_ Dellingemølle.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/023-0_ Veronica 1.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/023-0_ Veronica 1.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/023-0_ Veronica 1.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/039-0_ Holmegård nord.csv', '/Users/holmes/local_dev/agri_analysis/data/ledreborg_CSV/039-0_ Holme ...
# Extracting GeoJSON (API) for: /Users/holmes/local_dev/agri_analysis/data/TASKDATA
# Geo extraction returned: 0 (success)

# %%
# --- Display enhanced TASKDATA.XML report (with crop, TLG, sensors) ---
from pyagri.taskdata_report import taskdata_report

xml_path = PROJECT_ROOT / 'data' / 'taskdata' / 'TASKDATA.XML'
taskdata_report(xml_path)

# %%
import importlib
import pyagri.taskdata_report
importlib.reload(pyagri.taskdata_report)
from pyagri.taskdata_report import taskdata_report_df

# %%
# --- Display TASKDATA.XML report as a DataFrame ---
from pyagri.taskdata_report import taskdata_report_df
from IPython.display import display

xml_path = PROJECT_ROOT / 'data' / 'taskdata' / 'TASKDATA.XML'
df_report = taskdata_report_df(xml_path)
display(df_report)

# %% [markdown]
# ## Premlmary data analasis
# The data is now loaded and the following cells contain simpel valdation of the input

# %%
# --- GeoJSON Year Investigation ---
import geopandas as gpd
import pandas as pd
from IPython.display import display

# Load the GeoJSON file
gdf = gpd.read_file(FIELD_POLYGONS_GEOJSON)

# List all unique years in the 'Year' attribute
years = sorted(gdf['Year'].dropna().unique())
print(f"Unique years in GeoJSON: {years}")
display(pd.DataFrame({'Year': years}))

# %%
# Reproject GeoDataFrame to the target CRS for analysis
gdf_proj = gdf.to_crs(epsg=EPSG)
print(f"Reprojected GeoDataFrame to EPSG:{EPSG} for area/overlap analysis.")

# %%
# --- Check for overlapping polygons within each year (projected CRS) ---
from shapely.geometry import Polygon
from shapely.ops import unary_union

# Function to find overlapping polygons in a GeoDataFrame for a given year
def find_overlaps(gdf_year):
    overlaps = []
    for i, row1 in gdf_year.iterrows():
        for j, row2 in gdf_year.iterrows():
            if i >= j:
                continue
            if row1['geometry'].intersects(row2['geometry']):
                intersection = row1['geometry'].intersection(row2['geometry'])
                if not intersection.is_empty and intersection.area > 0:
                    overlaps.append((i, j, intersection.area))
    return overlaps

# Analyze overlaps for each year using the projected GeoDataFrame
overlap_summary = {}
for year in years:
    gdf_year = gdf_proj[gdf_proj['Year'] == year]
    overlaps = find_overlaps(gdf_year)
    overlap_summary[year] = overlaps
    print(f"Year {year}: {len(overlaps)} overlapping pairs found.")
    if overlaps:
        for i, j, area in overlaps:
            print(f"  Overlap between index {i} and {j}, area: {area:.2f} m²")

# Optionally, display summary as a DataFrame
overlap_counts = pd.DataFrame({
    'Year': list(overlap_summary.keys()),
    'Num Overlaps': [len(v) for v in overlap_summary.values()]
})
display(overlap_counts)

# %%
import xml.etree.ElementTree as ET
from collections import defaultdict
from datetime import datetime

def format_iso_time(iso_str):
    """Converts ISO 8601 string to human-readable 'YYYY-MM-DD HH:MM:SS'"""
    if not iso_str:
        return "Unknown"
    try:
        # Handle string slicing for simple conversion to avoid timezone library complexity
        # Expecting format like: 2023-08-16T12:39:28.000+02:00
        dt_str = iso_str.split('.')[0] # Remove milliseconds and timezone for display
        return dt_str.replace('T', ' ')
    except:
        return iso_str

def parse_isoxml_taskdata(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # --- 1. Extract Farm & Customer ---
    farms = {}
    for frm in root.findall('FRM'):
        farms[frm.attrib.get('A')] = frm.attrib.get('B', 'Unknown Farm')

    # --- 2. Extract Fields (PFD) ---
    fields = {}
    for pfd in root.findall('PFD'):
        pfd_id = pfd.attrib.get('A')
        name = pfd.attrib.get('C') or pfd.attrib.get('B') or f"Field {pfd_id}"
        fields[pfd_id] = name

    # --- 3. Extract Products/Crops (PDT) ---
    products = {}
    for pdt in root.findall('PDT'):
        products[pdt.attrib.get('A')] = pdt.attrib.get('B', 'Unknown Product')

    # --- 4. Extract Device Data (DVC, DET, DPD, DVP) ---
    # Map DET -> DVC, and store DPD/DVP definitions
    det_to_dvc = {}
    dvc_info = {}

    for dvc in root.findall('DVC'):
        dvc_id = dvc.attrib.get('A')
        dvc_name = dvc.attrib.get('B', 'Unknown Machine')
        
        for det in dvc.findall('.//DET'):
            det_to_dvc[det.attrib.get('A')] = dvc_id

        # Parse DVP (Value Presentation)
        dvp_map = {}
        for dvp in dvc.findall('.//DVP'):
            try:
                dvp_id = dvp.attrib.get('A')
                dvp_map[dvp_id] = {
                    'scale': float(dvp.attrib.get('C', 1)),
                    'offset': float(dvp.attrib.get('B', 0)),
                    'unit': dvp.attrib.get('E', '')
                }
            except: continue

        # Parse DPD (Process Data)
        dpd_map = {}
        for dpd in dvc.findall('.//DPD'):
            ddi = dpd.attrib.get('B')
            prop_name = dpd.attrib.get('E', f"DDI_{ddi}")
            dvp_ref = dpd.attrib.get('F')
            dpd_map[ddi] = {'name': prop_name, 'dvp': dvp_map.get(dvp_ref)}
            
        dvc_info[dvc_id] = {'name': dvc_name, 'dpds': dpd_map}

    # --- 5. Process Tasks (TSK) ---
    report_data = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

    for tsk in root.findall('TSK'):
        tsk_id = tsk.attrib.get('A')
        field_ref = tsk.attrib.get('E')
        
        field_name = fields.get(field_ref, f"Unknown Field ({field_ref})")

        # Crops
        task_crops = [products[pan.attrib.get('A')] for pan in tsk.findall('PAN') if pan.attrib.get('A') in products]
        crop_name = ", ".join(task_crops) if task_crops else "None"

        # Machine
        dan = tsk.find('DAN')
        machine_name = "Generic Machine"
        dvc_id_for_task = None
        if dan is not None:
            dvc_id_for_task = dan.attrib.get('C')
            if dvc_id_for_task in dvc_info:
                machine_name = dvc_info[dvc_id_for_task]['name']

        # TLG Files
        tlg_files = [tlg.attrib.get('A') for tlg in tsk.findall('TLG')]

        # --- Process Time & Values ---
        start_times = []
        end_times = []
        logged_values = []
        
        for tim in tsk.findall('TIM'):
            if 'A' in tim.attrib: start_times.append(tim.attrib['A'])
            if 'B' in tim.attrib: end_times.append(tim.attrib['B'])

            for dlv in tim.findall('DLV'):
                ddi = dlv.attrib.get('A')
                raw_value = int(dlv.attrib.get('B', 0))
                det_ref = dlv.attrib.get('C')
                
                # Default property info
                prop_name = f"DDI {ddi}"
                final_val = raw_value
                unit = ""
                
                # 1. Check Hardcoded Overrides (The "User Request" Layer)
                if ddi == '0106': # Fugtighed (Moisture)
                    prop_name = "Fugtighed"
                    final_val = raw_value * 0.0001
                    unit = "%"
                elif ddi == '013B': # Tørstofindhold (Dry Matter)
                    prop_name = "Tørstofindhold"
                    final_val = raw_value * 0.0001
                    unit = "%"
                
                # 2. If not overridden, look up DVP definitions in XML
                else:
                    current_dvc_id = det_to_dvc.get(det_ref, dvc_id_for_task)
                    if current_dvc_id and current_dvc_id in dvc_info:
                        dvc_defs = dvc_info[current_dvc_id]['dpds']
                        if ddi in dvc_defs:
                            def_info = dvc_defs[ddi]
                            prop_name = def_info['name']
                            if def_info['dvp']:
                                dvp = def_info['dvp']
                                final_val = (raw_value * dvp['scale']) + dvp['offset']
                                unit = dvp['unit']
                            # Standard fallback units if XML is missing DVP
                            elif ddi == '0074': unit = "m²"
                            elif ddi == '005A': unit = "kg"

                # Formatting
                if isinstance(final_val, float):
                    val_str = f"{final_val:,.2f}"
                else:
                    val_str = str(final_val)

                entry = f"{prop_name}: {val_str} {unit}"
                if entry not in logged_values:
                    logged_values.append(entry)

        # Determine overall start/end
        start_ts = min(start_times) if start_times else None
        end_ts = max(end_times) if end_times else None
        
        # Determine Year
        year = start_ts[:4] if start_ts else "Unknown Year"
        
        # Formatting Time
        time_range = f"{format_iso_time(start_ts)} - {format_iso_time(end_ts)}"

        task_info = {
            'TaskID': tsk_id,
            'Machine': machine_name,
            'Crop': crop_name,
            'TimeRange': time_range,
            'TLGs': tlg_files,
            'Properties': logged_values
        }
        
        farm_name = list(farms.values())[0] if farms else "Unknown Farm"
        report_data[farm_name][year][field_name].append(task_info)

    # --- 6. Print Report ---
    print(f"--- Agricultural Task Report ---\n")
    for farm, years in report_data.items():
        print(f"FARM: {farm}")
        for year in sorted(years.keys()):
            print(f"\n  YEAR: {year}")
            for field in sorted(years[year].keys()):
                print(f"    FIELD: {field}")
                for task in years[year][field]:
                    print(f"      TASK: {task['TaskID']}")
                    print(f"        Time: {task['TimeRange']}")
                    print(f"        Crop: {task['Crop']}")
                    print(f"        Machine: {task['Machine']}")
                    tlg_str = ', '.join(task['TLGs']) if task['TLGs'] else "None"
                    print(f"        TLG Files: {tlg_str}")
                    
                    if task['Properties']:
                        print(f"        Registered Properties (Totals):")
                        for prop in task['Properties']:
                            print(f"          - {prop}")
                    print("")

if __name__ == "__main__":
    parse_isoxml_taskdata(xml_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 197
#     194                     print("")
#     196 if __name__ == "__main__":
# --> 197     parse_isoxml_taskdata(xml_path)
#
# NameError: name 'xml_path' is not defined

# %%
xml_path = PROJECT_ROOT / 'data' / 'taskdata' / 'TASKDATA.XML'

# %%
import xml.etree.ElementTree as ET
from collections import defaultdict
from datetime import datetime

def format_iso_time(iso_str):
    """Converts ISO 8601 string to human-readable 'YYYY-MM-DD HH:MM:SS'"""
    if not iso_str:
        return "Unknown"
    try:
        # Handle string slicing for simple conversion to avoid timezone library complexity
        # Expecting format like: 2023-08-16T12:39:28.000+02:00
        dt_str = iso_str.split('.')[0] # Remove milliseconds and timezone for display
        return dt_str.replace('T', ' ')
    except:
        return iso_str

def parse_isoxml_taskdata(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # --- 1. Extract Farm & Customer ---
    farms = {}
    for frm in root.findall('FRM'):
        farms[frm.attrib.get('A')] = frm.attrib.get('B', 'Unknown Farm')

    # --- 2. Extract Fields (PFD) ---
    fields = {}
    for pfd in root.findall('PFD'):
        pfd_id = pfd.attrib.get('A')
        name = pfd.attrib.get('C') or pfd.attrib.get('B') or f"Field {pfd_id}"
        fields[pfd_id] = name

    # --- 3. Extract Products/Crops (PDT) ---
    products = {}
    for pdt in root.findall('PDT'):
        products[pdt.attrib.get('A')] = pdt.attrib.get('B', 'Unknown Product')

    # --- 4. Extract Device Data (DVC, DET, DPD, DVP) ---
    # Map DET -> DVC, and store DPD/DVP definitions
    det_to_dvc = {}
    dvc_info = {}

    for dvc in root.findall('DVC'):
        dvc_id = dvc.attrib.get('A')
        dvc_name = dvc.attrib.get('B', 'Unknown Machine')
        
        for det in dvc.findall('.//DET'):
            det_to_dvc[det.attrib.get('A')] = dvc_id

        # Parse DVP (Value Presentation)
        dvp_map = {}
        for dvp in dvc.findall('.//DVP'):
            try:
                dvp_id = dvp.attrib.get('A')
                dvp_map[dvp_id] = {
                    'scale': float(dvp.attrib.get('C', 1)),
                    'offset': float(dvp.attrib.get('B', 0)),
                    'unit': dvp.attrib.get('E', '')
                }
            except: continue

        # Parse DPD (Process Data)
        dpd_map = {}
        for dpd in dvc.findall('.//DPD'):
            ddi = dpd.attrib.get('B')
            prop_name = dpd.attrib.get('E', f"DDI_{ddi}")
            dvp_ref = dpd.attrib.get('F')
            dpd_map[ddi] = {'name': prop_name, 'dvp': dvp_map.get(dvp_ref)}
            
        dvc_info[dvc_id] = {'name': dvc_name, 'dpds': dpd_map}

    # --- 5. Process Tasks (TSK) ---
    report_data = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

    for tsk in root.findall('TSK'):
        tsk_id = tsk.attrib.get('A')
        field_ref = tsk.attrib.get('E')
        
        field_name = fields.get(field_ref, f"Unknown Field ({field_ref})")

        # Crops
        task_crops = [products[pan.attrib.get('A')] for pan in tsk.findall('PAN') if pan.attrib.get('A') in products]
        crop_name = ", ".join(task_crops) if task_crops else "None"

        # Machine
        dan = tsk.find('DAN')
        machine_name = "Generic Machine"
        dvc_id_for_task = None
        if dan is not None:
            dvc_id_for_task = dan.attrib.get('C')
            if dvc_id_for_task in dvc_info:
                machine_name = dvc_info[dvc_id_for_task]['name']

        # TLG Files
        tlg_files = [tlg.attrib.get('A') for tlg in tsk.findall('TLG')]

        # --- Process Time & Values ---
        start_times = []
        end_times = []
        logged_values = []
        
        for tim in tsk.findall('TIM'):
            if 'A' in tim.attrib: start_times.append(tim.attrib['A'])
            if 'B' in tim.attrib: end_times.append(tim.attrib['B'])

            for dlv in tim.findall('DLV'):
                ddi = dlv.attrib.get('A')
                raw_value = int(dlv.attrib.get('B', 0))
                det_ref = dlv.attrib.get('C')
                
                # Default property info
                prop_name = f"DDI {ddi}"
                final_val = raw_value
                unit = ""
                
                # 1. Check Hardcoded Overrides (The "User Request" Layer)
                if ddi == '0106': # Fugtighed (Moisture)
                    prop_name = "Fugtighed"
                    final_val = raw_value * 0.0001
                    unit = "%"
                elif ddi == '013B': # Tørstofindhold (Dry Matter)
                    prop_name = "Tørstofindhold"
                    final_val = raw_value * 0.0001
                    unit = "%"
                
                # 2. If not overridden, look up DVP definitions in XML
                else:
                    current_dvc_id = det_to_dvc.get(det_ref, dvc_id_for_task)
                    if current_dvc_id and current_dvc_id in dvc_info:
                        dvc_defs = dvc_info[current_dvc_id]['dpds']
                        if ddi in dvc_defs:
                            def_info = dvc_defs[ddi]
                            prop_name = def_info['name']
                            if def_info['dvp']:
                                dvp = def_info['dvp']
                                final_val = (raw_value * dvp['scale']) + dvp['offset']
                                unit = dvp['unit']
                            # Standard fallback units if XML is missing DVP
                            elif ddi == '0074': unit = "m²"
                            elif ddi == '005A': unit = "kg"

                # Formatting
                if isinstance(final_val, float):
                    val_str = f"{final_val:,.2f}"
                else:
                    val_str = str(final_val)

                entry = f"{prop_name}: {val_str} {unit}"
                if entry not in logged_values:
                    logged_values.append(entry)

        # Determine overall start/end
        start_ts = min(start_times) if start_times else None
        end_ts = max(end_times) if end_times else None
        
        # Determine Year
        year = start_ts[:4] if start_ts else "Unknown Year"
        
        # Formatting Time
        time_range = f"{format_iso_time(start_ts)} - {format_iso_time(end_ts)}"

        task_info = {
            'TaskID': tsk_id,
            'Machine': machine_name,
            'Crop': crop_name,
            'TimeRange': time_range,
            'TLGs': tlg_files,
            'Properties': logged_values
        }
        
        farm_name = list(farms.values())[0] if farms else "Unknown Farm"
        report_data[farm_name][year][field_name].append(task_info)

    # --- 6. Print Report ---
    print(f"--- Agricultural Task Report ---\n")
    for farm, years in report_data.items():
        print(f"FARM: {farm}")
        for year in sorted(years.keys()):
            print(f"\n  YEAR: {year}")
            for field in sorted(years[year].keys()):
                print(f"    FIELD: {field}")
                for task in years[year][field]:
                    print(f"      TASK: {task['TaskID']}")
                    print(f"        Time: {task['TimeRange']}")
                    print(f"        Crop: {task['Crop']}")
                    print(f"        Machine: {task['Machine']}")
                    tlg_str = ', '.join(task['TLGs']) if task['TLGs'] else "None"
                    print(f"        TLG Files: {tlg_str}")
                    
                    if task['Properties']:
                        print(f"        Registered Properties (Totals):")
                        for prop in task['Properties']:
                            print(f"          - {prop}")
                    print("")

if __name__ == "__main__":
    parse_isoxml_taskdata(xml_path)
# Out:
# --- Agricultural Task Report ---
#
# FARM: Ledreborg Gods
#
#   YEAR: 2022
#     FIELD: 002-0, St.Amalienborg/Litgoth
#       TASK: TSK189
#         Time: 2022-08-04 18:06:44 - 2022-08-13 22:30:35
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00123
#         Registered Properties (Totals):
#           - Bearb. areal: 125889 m²
#           - Varighed i alt: 12917
#           - Udbytte samlet masse: 98773 kg
#           - Fugtighed: 13.12 %
#           - Tørstofindhold: 86.88 %
#
#       TASK: TSK190
#         Time: 2022-08-04 18:06:44 - 2022-08-13 22:30:35
#         Crop: HV - Hvede
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00124
#         Registered Properties (Totals):
#           - Bearb. areal: 74253 m²
#           - Varighed i alt: 7273
#           - Udbytte samlet masse: 60713 kg
#           - Fugtighed: 13.12 %
#           - Tørstofindhold: 86.88 %
#
#       TASK: TSK191
#         Time: 2022-08-04 18:06:44 - 2022-08-13 22:30:35
#         Crop: HV - Hvede
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00125
#         Registered Properties (Totals):
#           - Bearb. areal: 77850 m²
#           - Varighed i alt: 7652
#           - Udbytte samlet masse: 64872 kg
#           - Fugtighed: 13.12 %
#           - Tørstofindhold: 86.88 %
#
#       TASK: TSK192
#         Time: 2022-08-04 18:06:44 - 2022-08-13 22:30:35
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 793431
#           - Udbytte samlet masse: 224 kg
#           - Fugtighed: 13.12 %
#           - Tørstofindhold: 86.88 %
#
#     FIELD: 010-0, Møllemark
#       TASK: TSK182
#         Time: 2022-08-13 14:32:41 - 2022-08-13 18:46:03
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00119
#         Registered Properties (Totals):
#           - Bearb. areal: 188442 m²
#           - Varighed i alt: 15202
#           - Udbytte samlet masse: 122805 kg
#           - Fugtighed: 14.19 %
#           - Tørstofindhold: 85.81 %
#
#       TASK: TSK183
#         Time: 2022-08-13 14:32:41 - 2022-08-13 18:46:03
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 15202
#           - Udbytte samlet masse: 123 kg
#           - Fugtighed: 14.19 %
#           - Tørstofindhold: 85.81 %
#
#     FIELD: 011-0, Akselbæk
#       TASK: TSK27
#         Time: 2022-08-13 11:58:22 - 2022-08-13 14:28:00
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00018
#         Registered Properties (Totals):
#           - Bearb. areal: 99780 m²
#           - Varighed i alt: 8978
#           - Udbytte samlet masse: 73744 kg
#           - Fugtighed: 14.44 %
#           - Tørstofindhold: 85.56 %
#
#       TASK: TSK28
#         Time: 2022-08-13 11:58:22 - 2022-08-13 14:28:00
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 8978
#           - Udbytte samlet masse: 74 kg
#           - Fugtighed: 14.44 %
#           - Tørstofindhold: 85.56 %
#
#     FIELD: 012-0, Hulegaardsmark
#       TASK: TSK130
#         Time: 2022-08-12 18:26:37 - 2022-08-13 11:58:06
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00085
#         Registered Properties (Totals):
#           - Bearb. areal: 255015 m²
#           - Varighed i alt: 21367
#           - Udbytte samlet masse: 194775 kg
#           - Fugtighed: 14.98 %
#           - Tørstofindhold: 85.02 %
#
#       TASK: TSK131
#         Time: 2022-08-12 18:26:37 - 2022-08-13 11:58:06
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 63089
#           - Udbytte samlet masse: 195 kg
#           - Fugtighed: 14.98 %
#           - Tørstofindhold: 85.02 %
#
#     FIELD: 013-0, Hulegaard b.
#       TASK: TSK87
#         Time: 2022-08-12 17:00:52 - 2022-08-12 18:25:56
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00057
#         Registered Properties (Totals):
#           - Bearb. areal: 57156 m²
#           - Varighed i alt: 4938
#           - Udbytte samlet masse: 36406 kg
#           - Fugtighed: 14.05 %
#           - Tørstofindhold: 85.95 %
#
#       TASK: TSK88
#         Time: 2022-08-12 17:00:52 - 2022-08-12 18:25:56
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 5104
#           - Udbytte samlet masse: 36 kg
#           - Fugtighed: 14.05 %
#           - Tørstofindhold: 85.95 %
#
#     FIELD: 015-0, Hulemølle
#       TASK: TSK96
#         Time: 2022-08-04 11:34:10 - 2022-08-04 17:45:51
#         Crop: HV - Hvede
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00063
#         Registered Properties (Totals):
#           - Bearb. areal: 100317 m²
#           - Varighed i alt: 10978
#           - Udbytte samlet masse: 83740 kg
#           - Fugtighed: 15.48 %
#           - Tørstofindhold: 84.52 %
#
#       TASK: TSK97
#         Time: 2022-08-04 11:34:10 - 2022-08-04 17:45:51
#         Crop: HV - Hvede
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00064
#         Registered Properties (Totals):
#           - Bearb. areal: 98914 m²
#           - Varighed i alt: 9787
#           - Udbytte samlet masse: 80885 kg
#           - Fugtighed: 15.48 %
#           - Tørstofindhold: 84.52 %
#
#       TASK: TSK98
#         Time: 2022-08-04 11:34:10 - 2022-08-04 17:45:51
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 22301
#           - Udbytte samlet masse: 165 kg
#           - Fugtighed: 15.48 %
#           - Tørstofindhold: 84.52 %
#
#     FIELD: 016-1, Stendyssegård Venstr
#       TASK: TSK209
#         Time: 2022-08-04 11:04:48 - 2022-08-04 11:51:10
#         Crop: HV - Hvede
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00137
#         Registered Properties (Totals):
#           - Bearb. areal: 24428 m²
#           - Varighed i alt: 2782
#           - Udbytte samlet masse: 19077 kg
#           - Fugtighed: 16.54 %
#           - Tørstofindhold: 83.46 %
#
#       TASK: TSK210
#         Time: 2022-08-04 11:04:48 - 2022-08-04 11:51:10
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 2782
#           - Udbytte samlet masse: 19 kg
#           - Fugtighed: 16.54 %
#           - Tørstofindhold: 83.46 %
#
#     FIELD: 016-2, Stendyssegård Højre
#       TASK: TSK14
#         Time: 2022-08-04 10:34:28 - 2022-08-04 11:04:34
#         Crop: HV - Hvede
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00010
#         Registered Properties (Totals):
#           - Bearb. areal: 16758 m²
#           - Varighed i alt: 1806
#           - Udbytte samlet masse: 13231 kg
#           - Fugtighed: 16.95 %
#           - Tørstofindhold: 83.05 %
#
#       TASK: TSK15
#         Time: 2022-08-04 10:34:28 - 2022-08-04 11:04:34
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 1806
#           - Udbytte samlet masse: 13 kg
#           - Fugtighed: 16.95 %
#           - Tørstofindhold: 83.05 %
#
#     FIELD: 022-0, Lidia
#       TASK: TSK58
#         Time: 2022-08-14 18:59:39 - 2022-08-15 20:58:38
#         Crop: VIB - Vinterbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00038
#         Registered Properties (Totals):
#           - Bearb. areal: 613100 m²
#           - Varighed i alt: 51521
#           - Udbytte samlet masse: 495037 kg
#           - Fugtighed: 15.47 %
#           - Tørstofindhold: 84.53 %
#
#       TASK: TSK59
#         Time: 2022-08-14 18:59:39 - 2022-08-15 20:58:38
#         Crop: VIB - Vinterbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 93539
#           - Udbytte samlet masse: 495 kg
#           - Fugtighed: 15.47 %
#           - Tørstofindhold: 84.53 %
#
#     FIELD: 035-0, Bispegård mark
#       TASK: TSK38
#         Time: 2022-08-04 10:54:04 - 2022-08-04 17:44:13
#         Crop: HV - Hvede
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00025
#         Registered Properties (Totals):
#           - Bearb. areal: 74427 m²
#           - Varighed i alt: 10940
#           - Udbytte samlet masse: 59157 kg
#           - Fugtighed: 14.21 %
#           - Tørstofindhold: 85.79 %
#
#       TASK: TSK39
#         Time: 2022-08-04 10:54:04 - 2022-08-04 17:44:13
#         Crop: HV - Hvede
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00026
#         Registered Properties (Totals):
#           - Bearb. areal: 85110 m²
#           - Varighed i alt: 10669
#           - Udbytte samlet masse: 69676 kg
#           - Fugtighed: 14.21 %
#           - Tørstofindhold: 85.79 %
#
#       TASK: TSK40
#         Time: 2022-08-04 10:54:04 - 2022-08-04 17:44:13
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 24609
#           - Udbytte samlet masse: 129 kg
#           - Fugtighed: 14.21 %
#           - Tørstofindhold: 85.79 %
#
#
#   YEAR: 2023
#     FIELD: 002-0, St.Amalienborg/Litgoth
#       TASK: TSK167
#         Time: 2023-08-15 20:58:16 - 2023-08-16 11:20:01
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00109
#         Registered Properties (Totals):
#           - Bearb. areal: 126535 m²
#           - Varighed i alt: 11707
#           - Udbytte samlet masse: 77754 kg
#           - Fugtighed: 14.95 %
#           - Tørstofindhold: 85.05 %
#
#       TASK: TSK168
#         Time: 2023-08-15 20:58:16 - 2023-08-16 11:20:01
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00110
#         Registered Properties (Totals):
#           - Bearb. areal: 153177 m²
#           - Varighed i alt: 11424
#           - Udbytte samlet masse: 96154 kg
#           - Fugtighed: 14.95 %
#           - Tørstofindhold: 85.05 %
#
#       TASK: TSK169
#         Time: 2023-08-15 20:58:16 - 2023-08-16 11:20:01
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 51705
#           - Udbytte samlet masse: 174 kg
#           - Fugtighed: 14.95 %
#           - Tørstofindhold: 85.05 %
#
#     FIELD: 010-0, Møllemark
#       TASK: TSK215
#         Time: 2023-08-16 11:34:57 - 2023-08-16 14:57:34
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00141
#         Registered Properties (Totals):
#           - Bearb. areal: 101146 m²
#           - Varighed i alt: 11580
#           - Udbytte samlet masse: 59587 kg
#           - Fugtighed: 15.07 %
#           - Tørstofindhold: 84.93 %
#
#       TASK: TSK216
#         Time: 2023-08-16 11:34:57 - 2023-08-16 14:57:34
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00142
#         Registered Properties (Totals):
#           - Bearb. areal: 89364 m²
#           - Varighed i alt: 8287
#           - Udbytte samlet masse: 51564 kg
#           - Fugtighed: 15.07 %
#           - Tørstofindhold: 84.93 %
#
#       TASK: TSK217
#         Time: 2023-08-16 11:34:57 - 2023-08-16 14:57:34
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 12157
#           - Udbytte samlet masse: 111 kg
#           - Fugtighed: 15.07 %
#           - Tørstofindhold: 84.93 %
#
#     FIELD: 011-0, Akselbæk
#       TASK: TSK16
#         Time: 2023-08-16 17:51:04 - 2023-08-16 19:02:29
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00011
#         Registered Properties (Totals):
#           - Bearb. areal: 54454 m²
#           - Varighed i alt: 4226
#           - Udbytte samlet masse: 26224 kg
#           - Fugtighed: 12.98 %
#           - Tørstofindhold: 87.02 %
#
#       TASK: TSK17
#         Time: 2023-08-16 17:51:04 - 2023-08-16 19:02:29
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00012
#         Registered Properties (Totals):
#           - Bearb. areal: 45975 m²
#           - Varighed i alt: 3803
#           - Udbytte samlet masse: 26362 kg
#           - Fugtighed: 12.98 %
#           - Tørstofindhold: 87.02 %
#
#       TASK: TSK18
#         Time: 2023-08-16 17:51:04 - 2023-08-16 19:02:29
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 4285
#           - Udbytte samlet masse: 53 kg
#           - Fugtighed: 12.98 %
#           - Tørstofindhold: 87.02 %
#
#     FIELD: 012-0, Hulegaardsmark
#       TASK: TSK135
#         Time: 2023-08-06 16:42:16 - 2023-08-16 21:56:33
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00088
#         Registered Properties (Totals):
#           - Bearb. areal: 157641 m²
#           - Varighed i alt: 17727
#           - Udbytte samlet masse: 105991 kg
#           - Fugtighed: 13.09 %
#           - Tørstofindhold: 86.91 %
#
#       TASK: TSK136
#         Time: 2023-08-06 16:42:16 - 2023-08-16 21:56:33
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00089
#         Registered Properties (Totals):
#           - Bearb. areal: 99323 m²
#           - Varighed i alt: 11232
#           - Udbytte samlet masse: 59552 kg
#           - Fugtighed: 13.09 %
#           - Tørstofindhold: 86.91 %
#
#       TASK: TSK137
#         Time: 2023-08-06 16:42:16 - 2023-08-16 21:56:33
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 882857
#           - Udbytte samlet masse: 166 kg
#           - Fugtighed: 13.09 %
#           - Tørstofindhold: 86.91 %
#
#     FIELD: 013-0, Hulegaard b.
#       TASK: TSK164
#         Time: 2023-08-06 15:46:56 - 2023-08-16 21:44:43
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00107
#         Registered Properties (Totals):
#           - Bearb. areal: 18218 m²
#           - Varighed i alt: 3000
#           - Udbytte samlet masse: 6481 kg
#           - Fugtighed: 14.71 %
#           - Tørstofindhold: 85.29 %
#
#       TASK: TSK165
#         Time: 2023-08-06 15:46:56 - 2023-08-16 21:44:43
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00108
#         Registered Properties (Totals):
#           - Bearb. areal: 39233 m²
#           - Varighed i alt: 3700
#           - Udbytte samlet masse: 24882 kg
#           - Fugtighed: 14.71 %
#           - Tørstofindhold: 85.29 %
#
#       TASK: TSK166
#         Time: 2023-08-06 15:46:56 - 2023-08-16 21:44:43
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 885467
#           - Udbytte samlet masse: 31 kg
#           - Fugtighed: 14.71 %
#           - Tørstofindhold: 85.29 %
#
#     FIELD: 014-0, Dellingemølle
#       TASK: TSK44
#         Time: 2023-08-16 14:16:30 - 2023-08-16 16:58:20
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00029
#         Registered Properties (Totals):
#           - Bearb. areal: 112028 m²
#           - Varighed i alt: 8960
#           - Udbytte samlet masse: 67852 kg
#           - Fugtighed: 14.15 %
#           - Tørstofindhold: 85.85 %
#
#       TASK: TSK45
#         Time: 2023-08-16 14:16:30 - 2023-08-16 16:58:20
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 9710
#           - Udbytte samlet masse: 68 kg
#           - Fugtighed: 14.15 %
#           - Tørstofindhold: 85.85 %
#
#     FIELD: 015-0, Hulemølle
#       TASK: TSK32
#         Time: 2023-08-15 10:28:54 - 2023-08-15 13:21:40
#         Crop: VIB - Vinterbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00021
#         Registered Properties (Totals):
#           - Bearb. areal: 88836 m²
#           - Varighed i alt: 10235
#           - Udbytte samlet masse: 35084 kg
#           - Fugtighed: 16.89 %
#           - Tørstofindhold: 83.11 %
#
#       TASK: TSK33
#         Time: 2023-08-15 10:28:54 - 2023-08-15 13:21:40
#         Crop: VIB - Vinterbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00022
#         Registered Properties (Totals):
#           - Bearb. areal: 111236 m²
#           - Varighed i alt: 9680
#           - Udbytte samlet masse: 45244 kg
#           - Fugtighed: 16.89 %
#           - Tørstofindhold: 83.11 %
#
#       TASK: TSK34
#         Time: 2023-08-15 10:28:54 - 2023-08-15 13:21:40
#         Crop: VIB - Vinterbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 10366
#           - Udbytte samlet masse: 80 kg
#           - Fugtighed: 16.89 %
#           - Tørstofindhold: 83.11 %
#
#     FIELD: 016-0, Stendyssegård
#       TASK: TSK146
#         Time: 2023-08-14 19:52:36 - 2023-08-14 21:06:11
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00095
#         Registered Properties (Totals):
#           - Bearb. areal: 52277 m²
#           - Varighed i alt: 4005
#           - Udbytte samlet masse: 15076 kg
#           - Fugtighed: 16.79 %
#           - Tørstofindhold: 83.21 %
#
#       TASK: TSK147
#         Time: 2023-08-14 19:52:36 - 2023-08-14 21:06:11
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00096
#         Registered Properties (Totals):
#           - Bearb. areal: 55859 m²
#           - Varighed i alt: 4396
#           - Udbytte samlet masse: 18776 kg
#           - Fugtighed: 16.79 %
#           - Tørstofindhold: 83.21 %
#
#       TASK: TSK148
#         Time: 2023-08-14 19:52:36 - 2023-08-14 21:06:11
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 4415
#           - Udbytte samlet masse: 34 kg
#           - Fugtighed: 16.79 %
#           - Tørstofindhold: 83.21 %
#
#     FIELD: 016-1, Stendyssegård Venstr
#       TASK: TSK149
#         Time: 2023-08-14 21:18:21 - 2023-08-15 10:36:10
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00097
#         Registered Properties (Totals):
#           - Bearb. areal: 5518 m²
#           - Varighed i alt: 870
#           - Udbytte samlet masse: 1800 kg
#           - Fugtighed: 16.87 %
#           - Tørstofindhold: 83.13 %
#
#       TASK: TSK150
#         Time: 2023-08-14 21:18:21 - 2023-08-15 10:36:10
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00098
#         Registered Properties (Totals):
#           - Bearb. areal: 18926 m²
#           - Varighed i alt: 2791
#           - Udbytte samlet masse: 7955 kg
#           - Fugtighed: 16.87 %
#           - Tørstofindhold: 83.13 %
#
#       TASK: TSK151
#         Time: 2023-08-14 21:18:21 - 2023-08-15 10:36:10
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 47869
#           - Udbytte samlet masse: 10 kg
#           - Fugtighed: 16.87 %
#           - Tørstofindhold: 83.13 %
#
#     FIELD: 016-2, Stendyssegård Højre
#       TASK: TSK55
#         Time: 2023-08-14 21:08:47 - 2023-08-15 10:37:50
#         Crop: VIB - Vinterbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00036
#         Registered Properties (Totals):
#           - Bearb. areal: 10682 m²
#           - Varighed i alt: 1385
#           - Udbytte samlet masse: 2912 kg
#           - Fugtighed: 17.27 %
#           - Tørstofindhold: 82.73 %
#
#       TASK: TSK56
#         Time: 2023-08-14 21:08:47 - 2023-08-15 10:37:50
#         Crop: VIB - Vinterbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00037
#         Registered Properties (Totals):
#           - Bearb. areal: 6324 m²
#           - Varighed i alt: 650
#           - Udbytte samlet masse: 2090 kg
#           - Fugtighed: 17.27 %
#           - Tørstofindhold: 82.73 %
#
#       TASK: TSK57
#         Time: 2023-08-14 21:08:47 - 2023-08-15 10:37:50
#         Crop: VIB - Vinterbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 48543
#           - Udbytte samlet masse: 5 kg
#           - Fugtighed: 17.27 %
#           - Tørstofindhold: 82.73 %
#
#     FIELD: 021-0, Monica
#       TASK: TSK116
#         Time: 2023-08-14 10:33:46 - 2023-08-14 12:42:26
#         Crop: VIB - Vinterbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00076
#         Registered Properties (Totals):
#           - Bearb. areal: 69409 m²
#           - Varighed i alt: 7720
#           - Udbytte samlet masse: 31157 kg
#           - Fugtighed: 16.71 %
#           - Tørstofindhold: 83.29 %
#
#       TASK: TSK117
#         Time: 2023-08-14 10:33:46 - 2023-08-14 12:42:26
#         Crop: VIB - Vinterbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 7720
#           - Udbytte samlet masse: 31 kg
#           - Fugtighed: 16.71 %
#           - Tørstofindhold: 83.29 %
#
#     FIELD: 022-0, Lidia
#       TASK: TSK10
#         Time: 2023-07-18 13:55:19 - 2023-07-19 17:04:02
#         Crop: RG - Rajgræs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00007
#         Registered Properties (Totals):
#           - Bearb. areal: 209130 m²
#           - Varighed i alt: 49577
#           - Udbytte samlet masse: 27137 kg
#           - Fugtighed: 14.87 %
#           - Tørstofindhold: 85.13 %
#
#       TASK: TSK11
#         Time: 2023-07-18 13:55:19 - 2023-07-19 17:04:02
#         Crop: RG - Rajgræs
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00008
#         Registered Properties (Totals):
#           - Bearb. areal: 208536 m²
#           - Varighed i alt: 53916
#           - Udbytte samlet masse: 23974 kg
#           - Fugtighed: 14.87 %
#           - Tørstofindhold: 85.13 %
#
#       TASK: TSK12
#         Time: 2023-07-18 13:55:19 - 2023-07-19 17:04:02
#         Crop: RG - Rajgræs
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00009
#         Registered Properties (Totals):
#           - Bearb. areal: 188038 m²
#           - Varighed i alt: 47268
#           - Udbytte samlet masse: 27008 kg
#           - Fugtighed: 14.87 %
#           - Tørstofindhold: 85.13 %
#
#       TASK: TSK13
#         Time: 2023-07-18 13:55:19 - 2023-07-19 17:04:02
#         Crop: RG - Rajgræs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 97723
#           - Udbytte samlet masse: 78 kg
#           - Fugtighed: 14.87 %
#           - Tørstofindhold: 85.13 %
#
#     FIELD: 023-0, Veronica 1
#       TASK: TSK46
#         Time: 2023-08-06 11:45:32 - 2023-08-06 13:07:43
#         Crop: RA - Raps / rybs
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00030
#         Registered Properties (Totals):
#           - Bearb. areal: 36514 m²
#           - Varighed i alt: 3150
#           - Udbytte samlet masse: 5454 kg
#           - Fugtighed: 14.69 %
#           - Tørstofindhold: 85.31 %
#
#       TASK: TSK47
#         Time: 2023-08-06 11:45:32 - 2023-08-06 13:07:43
#         Crop: RA - Raps / rybs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00031
#         Registered Properties (Totals):
#           - Bearb. areal: 40858 m²
#           - Varighed i alt: 2766
#           - Udbytte samlet masse: 9039 kg
#           - Fugtighed: 14.69 %
#           - Tørstofindhold: 85.31 %
#
#       TASK: TSK48
#         Time: 2023-08-06 11:45:32 - 2023-08-06 13:07:43
#         Crop: RA - Raps / rybs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 4931
#           - Udbytte samlet masse: 14 kg
#           - Fugtighed: 14.69 %
#           - Tørstofindhold: 85.31 %
#
#     FIELD: 023-2, Veronica 2
#       TASK: TSK21
#         Time: 2023-08-06 12:00:03 - 2023-08-06 12:29:10
#         Crop: RA - Raps / rybs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00014
#         Registered Properties (Totals):
#           - Bearb. areal: 21606 m²
#           - Varighed i alt: 1685
#           - Udbytte samlet masse: 6560 kg
#           - Fugtighed: 12.69 %
#           - Tørstofindhold: 87.31 %
#
#       TASK: TSK22
#         Time: 2023-08-06 12:00:03 - 2023-08-06 12:29:10
#         Crop: RA - Raps / rybs
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00015
#         Registered Properties (Totals):
#           - Bearb. areal: 19228 m²
#           - Varighed i alt: 1717
#           - Udbytte samlet masse: 4043 kg
#           - Fugtighed: 12.69 %
#           - Tørstofindhold: 87.31 %
#
#       TASK: TSK23
#         Time: 2023-08-06 12:00:03 - 2023-08-06 12:29:10
#         Crop: RA - Raps / rybs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 1747
#           - Udbytte samlet masse: 11 kg
#           - Fugtighed: 12.69 %
#           - Tørstofindhold: 87.31 %
#
#     FIELD: 024-0, Silvia
#       TASK: TSK93
#         Time: 2023-08-14 12:46:41 - 2023-08-14 17:08:41
#         Crop: VIB - Vinterbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00061
#         Registered Properties (Totals):
#           - Bearb. areal: 162915 m²
#           - Varighed i alt: 15720
#           - Udbytte samlet masse: 85457 kg
#           - Fugtighed: 15.68 %
#           - Tørstofindhold: 84.32 %
#
#       TASK: TSK94
#         Time: 2023-08-14 12:46:41 - 2023-08-14 17:08:41
#         Crop: VIB - Vinterbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00062
#         Registered Properties (Totals):
#           - Bearb. areal: 68472 m²
#           - Varighed i alt: 4767
#           - Udbytte samlet masse: 36923 kg
#           - Fugtighed: 15.68 %
#           - Tørstofindhold: 84.32 %
#
#       TASK: TSK95
#         Time: 2023-08-14 12:46:41 - 2023-08-14 17:08:41
#         Crop: VIB - Vinterbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 15720
#           - Udbytte samlet masse: 122 kg
#           - Fugtighed: 15.68 %
#           - Tørstofindhold: 84.32 %
#
#     FIELD: 025-0, Camilla/Tatiana
#       TASK: TSK104
#         Time: 2023-08-06 09:54:32 - 2023-08-16 17:18:50
#         Crop: RA - Raps / rybs
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00068
#         Registered Properties (Totals):
#           - Bearb. areal: 180511 m²
#           - Varighed i alt: 14650
#           - Udbytte samlet masse: 30866 kg
#           - Fugtighed: 13.70 %
#           - Tørstofindhold: 86.30 %
#
#       TASK: TSK105
#         Time: 2023-08-06 09:54:32 - 2023-08-16 17:18:50
#         Crop: RA - Raps / rybs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00069
#         Registered Properties (Totals):
#           - Bearb. areal: 198921 m²
#           - Varighed i alt: 14761
#           - Udbytte samlet masse: 51086 kg
#           - Fugtighed: 13.70 %
#           - Tørstofindhold: 86.30 %
#
#       TASK: TSK106
#         Time: 2023-08-06 09:54:32 - 2023-08-16 17:18:50
#         Crop: RA - Raps / rybs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 890658
#           - Udbytte samlet masse: 82 kg
#           - Fugtighed: 13.70 %
#           - Tørstofindhold: 86.30 %
#
#     FIELD: 035-0, Bispegård mark
#       TASK: TSK84
#         Time: 2023-08-15 13:20:29 - 2023-08-15 20:31:11
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00055
#         Registered Properties (Totals):
#           - Bearb. areal: 93523 m²
#           - Varighed i alt: 10523
#           - Udbytte samlet masse: 34823 kg
#           - Fugtighed: 16.20 %
#           - Tørstofindhold: 83.80 %
#
#       TASK: TSK85
#         Time: 2023-08-15 13:20:29 - 2023-08-15 20:31:11
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00056
#         Registered Properties (Totals):
#           - Bearb. areal: 74586 m²
#           - Varighed i alt: 8567
#           - Udbytte samlet masse: 27706 kg
#           - Fugtighed: 16.20 %
#           - Tørstofindhold: 83.80 %
#
#       TASK: TSK86
#         Time: 2023-08-15 13:20:29 - 2023-08-15 20:31:11
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 25842
#           - Udbytte samlet masse: 63 kg
#           - Fugtighed: 16.20 %
#           - Tørstofindhold: 83.80 %
#
#     FIELD: 036-0, Bispegård vest
#       TASK: TSK109
#         Time: 2023-08-14 16:50:39 - 2023-08-14 19:49:01
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00071
#         Registered Properties (Totals):
#           - Bearb. areal: 63770 m²
#           - Varighed i alt: 6975
#           - Udbytte samlet masse: 24184 kg
#           - Fugtighed: 16.08 %
#           - Tørstofindhold: 83.92 %
#
#       TASK: TSK110
#         Time: 2023-08-14 16:50:39 - 2023-08-14 19:49:01
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00072
#         Registered Properties (Totals):
#           - Bearb. areal: 30057 m²
#           - Varighed i alt: 3875
#           - Udbytte samlet masse: 9627 kg
#           - Fugtighed: 16.08 %
#           - Tørstofindhold: 83.92 %
#
#       TASK: TSK111
#         Time: 2023-08-14 16:50:39 - 2023-08-14 19:49:01
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 10702
#           - Udbytte samlet masse: 34 kg
#           - Fugtighed: 16.08 %
#           - Tørstofindhold: 83.92 %
#
#     FIELD: 037-0, Bispegård øst
#       TASK: TSK107
#         Time: 2023-08-14 19:03:31 - 2023-08-14 19:40:01
#         Crop: VIB - Vinterbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00070
#         Registered Properties (Totals):
#           - Bearb. areal: 23289 m²
#           - Varighed i alt: 2190
#           - Udbytte samlet masse: 6393 kg
#           - Fugtighed: 17.04 %
#           - Tørstofindhold: 82.96 %
#
#       TASK: TSK108
#         Time: 2023-08-14 19:03:31 - 2023-08-14 19:40:01
#         Crop: VIB - Vinterbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 2190
#           - Udbytte samlet masse: 6 kg
#           - Fugtighed: 17.04 %
#           - Tørstofindhold: 82.96 %
#
#     FIELD: B011-1, Brak - Akselbæk nord
#       TASK: TSK173
#         Time: 2023-08-16 18:04:04 - 2023-08-16 18:07:25
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00113
#         Registered Properties (Totals):
#           - Bearb. areal: 1141 m²
#           - Varighed i alt: 201
#           - Udbytte samlet masse: 725 kg
#           - Fugtighed: 14.16 %
#           - Tørstofindhold: 85.84 %
#
#       TASK: TSK174
#         Time: 2023-08-16 18:04:04 - 2023-08-16 18:07:25
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 201
#           - Udbytte samlet masse: 1 kg
#           - Fugtighed: 14.16 %
#           - Tørstofindhold: 85.84 %
#
#     FIELD: B025-1, Brak - C/T Syd
#       TASK: TSK19
#         Time: 2023-08-06 11:57:38 - 2023-08-06 11:59:48
#         Crop: RA - Raps / rybs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00013
#         Registered Properties (Totals):
#           - Bearb. areal: 9574 m²
#           - Varighed i alt: 130
#           - Udbytte samlet masse: 10 kg
#
#       TASK: TSK20
#         Time: 2023-08-06 11:57:38 - 2023-08-06 11:59:48
#         Crop: RA - Raps / rybs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 130
#           - Udbytte samlet masse: 0 kg
#
#     FIELD: M025-6
#       TASK: TSK128
#         Time: 2023-08-06 10:10:28 - 2023-08-06 10:11:53
#         Crop: RA - Raps / rybs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00084
#         Registered Properties (Totals):
#           - Bearb. areal: 122 m²
#           - Varighed i alt: 85
#           - Udbytte samlet masse: 52 kg
#           - Fugtighed: 13.30 %
#           - Tørstofindhold: 86.70 %
#
#       TASK: TSK129
#         Time: 2023-08-06 10:10:28 - 2023-08-06 10:11:53
#         Crop: RA - Raps / rybs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 85
#           - Udbytte samlet masse: 0 kg
#           - Fugtighed: 13.30 %
#           - Tørstofindhold: 86.70 %
#
#
#   YEAR: 2024
#     FIELD: 002-0, St.Amalienborg
#       TASK: TSK132
#         Time: 2024-08-12 15:55:05 - 2024-08-12 21:27:17
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00086
#         Registered Properties (Totals):
#           - Bearb. areal: 148517 m²
#           - Varighed i alt: 19315
#           - Udbytte samlet masse: 97738 kg
#           - Fugtighed: 14.49 %
#           - Tørstofindhold: 85.51 %
#
#       TASK: TSK133
#         Time: 2024-08-12 15:55:05 - 2024-08-12 21:27:17
#         Crop: VB - Vårbyg
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00087
#         Registered Properties (Totals):
#           - Bearb. areal: 125062 m²
#           - Varighed i alt: 18269
#           - Udbytte samlet masse: 87463 kg
#           - Fugtighed: 14.49 %
#           - Tørstofindhold: 85.51 %
#
#       TASK: TSK134
#         Time: 2024-08-12 15:55:05 - 2024-08-12 21:27:17
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 19932
#           - Udbytte samlet masse: 185 kg
#           - Fugtighed: 14.49 %
#           - Tørstofindhold: 85.51 %
#
#     FIELD: 010-0, Møllemark
#       TASK: TSK63
#         Time: 2024-08-13 08:45:23 - 2024-08-13 12:19:14
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00041
#         Registered Properties (Totals):
#           - Bearb. areal: 86038 m²
#           - Varighed i alt: 10852
#           - Udbytte samlet masse: 40568 kg
#           - Fugtighed: 16.32 %
#           - Tørstofindhold: 83.68 %
#
#       TASK: TSK64
#         Time: 2024-08-13 08:45:23 - 2024-08-13 12:19:14
#         Crop: VB - Vårbyg
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00042
#         Registered Properties (Totals):
#           - Bearb. areal: 91752 m²
#           - Varighed i alt: 11715
#           - Udbytte samlet masse: 47975 kg
#           - Fugtighed: 16.32 %
#           - Tørstofindhold: 83.68 %
#
#       TASK: TSK65
#         Time: 2024-08-13 08:45:23 - 2024-08-13 12:19:14
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 12831
#           - Udbytte samlet masse: 89 kg
#           - Fugtighed: 16.32 %
#           - Tørstofindhold: 83.68 %
#
#     FIELD: 011-0, Akselbæk
#       TASK: TSK186
#         Time: 2024-08-12 12:08:05 - 2024-08-12 14:05:27
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00121
#         Registered Properties (Totals):
#           - Bearb. areal: 46008 m²
#           - Varighed i alt: 6800
#           - Udbytte samlet masse: 32843 kg
#           - Fugtighed: 13.78 %
#           - Tørstofindhold: 86.22 %
#
#       TASK: TSK187
#         Time: 2024-08-12 12:08:05 - 2024-08-12 14:05:27
#         Crop: HV - Hvede
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00122
#         Registered Properties (Totals):
#           - Bearb. areal: 52937 m²
#           - Varighed i alt: 6903
#           - Udbytte samlet masse: 35583 kg
#           - Fugtighed: 13.78 %
#           - Tørstofindhold: 86.22 %
#
#       TASK: TSK188
#         Time: 2024-08-12 12:08:05 - 2024-08-12 14:05:27
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 7042
#           - Udbytte samlet masse: 68 kg
#           - Fugtighed: 13.78 %
#           - Tørstofindhold: 86.22 %
#
#     FIELD: 012-0, Hulegaardsmark
#       TASK: TSK29
#         Time: 2024-08-11 19:54:05 - 2024-08-12 14:47:19
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00019
#         Registered Properties (Totals):
#           - Bearb. areal: 137344 m²
#           - Varighed i alt: 15486
#           - Udbytte samlet masse: 101856 kg
#           - Fugtighed: 14.00 %
#           - Tørstofindhold: 86.00 %
#
#       TASK: TSK30
#         Time: 2024-08-11 19:54:05 - 2024-08-12 14:47:19
#         Crop: HV - Hvede
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00020
#         Registered Properties (Totals):
#           - Bearb. areal: 115716 m²
#           - Varighed i alt: 14495
#           - Udbytte samlet masse: 82739 kg
#           - Fugtighed: 14.00 %
#           - Tørstofindhold: 86.00 %
#
#       TASK: TSK31
#         Time: 2024-08-11 19:54:05 - 2024-08-12 14:47:19
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 67994
#           - Udbytte samlet masse: 185 kg
#           - Fugtighed: 14.00 %
#           - Tørstofindhold: 86.00 %
#
#     FIELD: 013-0, Hulegaard b.
#       TASK: TSK179
#         Time: 2024-08-11 18:39:06 - 2024-08-12 14:49:39
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00117
#         Registered Properties (Totals):
#           - Bearb. areal: 27748 m²
#           - Varighed i alt: 3440
#           - Udbytte samlet masse: 18995 kg
#           - Fugtighed: 12.43 %
#           - Tørstofindhold: 87.57 %
#
#       TASK: TSK180
#         Time: 2024-08-11 18:39:06 - 2024-08-12 14:49:39
#         Crop: HV - Hvede
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00118
#         Registered Properties (Totals):
#           - Bearb. areal: 27973 m²
#           - Varighed i alt: 3595
#           - Udbytte samlet masse: 19265 kg
#           - Fugtighed: 12.43 %
#           - Tørstofindhold: 87.57 %
#
#       TASK: TSK181
#         Time: 2024-08-11 18:39:06 - 2024-08-12 14:49:39
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 72633
#           - Udbytte samlet masse: 38 kg
#           - Fugtighed: 12.43 %
#           - Tørstofindhold: 87.57 %
#
#     FIELD: 014-0, Dellingemølle
#       TASK: TSK184
#         Time: 2024-08-28 15:17:14 - 2024-08-28 21:32:20
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00120
#         Registered Properties (Totals):
#           - Bearb. areal: 112434 m²
#           - Varighed i alt: 20025
#           - Udbytte samlet masse: 41514 kg
#           - Fugtighed: 14.35 %
#           - Tørstofindhold: 85.65 %
#
#       TASK: TSK185
#         Time: 2024-08-28 15:17:14 - 2024-08-28 21:32:20
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 22506
#           - Udbytte samlet masse: 42 kg
#           - Fugtighed: 14.35 %
#           - Tørstofindhold: 85.65 %
#
#     FIELD: 015-0, Hulemølle
#       TASK: TSK75
#         Time: 2024-07-20 20:52:48 - 2024-07-29 13:37:20
#         Crop: RG - Rajgræs
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00049
#         Registered Properties (Totals):
#           - Bearb. areal: 100196 m²
#           - Varighed i alt: 42665
#           - Udbytte samlet masse: 18057 kg
#           - Fugtighed: 5.45 %
#           - Tørstofindhold: 94.55 %
#
#       TASK: TSK76
#         Time: 2024-07-20 20:52:48 - 2024-07-29 13:37:20
#         Crop: RG - Rajgræs
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00050
#         Registered Properties (Totals):
#           - Bearb. areal: 100178 m²
#           - Varighed i alt: 41274
#           - Udbytte samlet masse: 19741 kg
#           - Fugtighed: 5.45 %
#           - Tørstofindhold: 94.55 %
#
#       TASK: TSK77
#         Time: 2024-07-20 20:52:48 - 2024-07-29 13:37:20
#         Crop: RG - Rajgræs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 751472
#           - Udbytte samlet masse: 38 kg
#           - Fugtighed: 5.45 %
#           - Tørstofindhold: 94.55 %
#
#     FIELD: 016-0, Stendyssegård
#       TASK: TSK211
#         Time: 2024-07-30 18:35:12 - 2024-07-31 15:17:25
#         Crop: RG - Rajgræs
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00138
#         Registered Properties (Totals):
#           - Bearb. areal: 21640 m²
#           - Varighed i alt: 11750
#           - Udbytte samlet masse: 1866 kg
#
#       TASK: TSK212
#         Time: 2024-07-30 18:35:12 - 2024-07-31 15:17:25
#         Crop: RG - Rajgræs
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00139
#         Registered Properties (Totals):
#           - Bearb. areal: 60911 m²
#           - Varighed i alt: 29595
#           - Udbytte samlet masse: 7287 kg
#
#       TASK: TSK213
#         Time: 2024-07-30 18:35:12 - 2024-07-31 15:17:25
#         Crop: RG - Rajgræs
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00140
#         Registered Properties (Totals):
#           - Bearb. areal: 21433 m²
#           - Varighed i alt: 12700
#           - Udbytte samlet masse: 1186 kg
#
#       TASK: TSK214
#         Time: 2024-07-30 18:35:12 - 2024-07-31 15:17:25
#         Crop: RG - Rajgræs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 74533
#           - Udbytte samlet masse: 10 kg
#
#     FIELD: 016-1, Stendyssegård Venstr
#       TASK: TSK89
#         Time: 2024-07-30 17:22:22 - 2024-07-30 18:53:06
#         Crop: RG - Rajgræs
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00058
#         Registered Properties (Totals):
#           - Bearb. areal: 6561 m²
#           - Varighed i alt: 3105
#           - Udbytte samlet masse: 824 kg
#
#       TASK: TSK90
#         Time: 2024-07-30 17:22:22 - 2024-07-30 18:53:06
#         Crop: RG - Rajgræs
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00059
#         Registered Properties (Totals):
#           - Bearb. areal: 8617 m²
#           - Varighed i alt: 3470
#           - Udbytte samlet masse: 620 kg
#
#       TASK: TSK91
#         Time: 2024-07-30 17:22:22 - 2024-07-30 18:53:06
#         Crop: RG - Rajgræs
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00060
#         Registered Properties (Totals):
#           - Bearb. areal: 7281 m²
#           - Varighed i alt: 4280
#           - Udbytte samlet masse: 510 kg
#
#       TASK: TSK92
#         Time: 2024-07-30 17:22:22 - 2024-07-30 18:53:06
#         Crop: RG - Rajgræs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 5444
#           - Udbytte samlet masse: 2 kg
#
#     FIELD: 016-2, Stendyssegård Højre
#       TASK: TSK199
#         Time: 2024-07-29 13:39:08 - 2024-07-30 17:57:27
#         Crop: RG - Rajgræs
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00130
#         Registered Properties (Totals):
#           - Bearb. areal: 6196 m²
#           - Varighed i alt: 3458
#           - Udbytte samlet masse: 430 kg
#
#       TASK: TSK200
#         Time: 2024-07-29 13:39:08 - 2024-07-30 17:57:27
#         Crop: RG - Rajgræs
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00131
#         Registered Properties (Totals):
#           - Bearb. areal: 7060 m²
#           - Varighed i alt: 5407
#           - Udbytte samlet masse: 1191 kg
#
#       TASK: TSK201
#         Time: 2024-07-29 13:39:08 - 2024-07-30 17:57:27
#         Crop: RG - Rajgræs
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00132
#         Registered Properties (Totals):
#           - Bearb. areal: 2858 m²
#           - Varighed i alt: 1485
#           - Udbytte samlet masse: 187 kg
#
#       TASK: TSK202
#         Time: 2024-07-29 13:39:08 - 2024-07-30 17:57:27
#         Crop: RG - Rajgræs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 101899
#           - Udbytte samlet masse: 2 kg
#
#     FIELD: 016-3, Stendysegård fold
#       TASK: TSK102
#         Time: 2024-08-13 12:42:52 - 2024-08-13 16:16:49
#         Crop: VB - Vårbyg
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00067
#         Registered Properties (Totals):
#           - Bearb. areal: 25878 m²
#           - Varighed i alt: 2467
#           - Udbytte samlet masse: 15731 kg
#           - Fugtighed: 14.89 %
#           - Tørstofindhold: 85.11 %
#
#       TASK: TSK103
#         Time: 2024-08-13 12:42:52 - 2024-08-13 16:16:49
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 12837
#           - Udbytte samlet masse: 16 kg
#           - Fugtighed: 14.89 %
#           - Tørstofindhold: 85.11 %
#
#     FIELD: 021-0, Monica
#       TASK: TSK1
#         Time: 2024-07-30 20:44:39 - 2024-07-31 12:48:54
#         Crop: RA - Raps / rybs
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00001
#         Registered Properties (Totals):
#           - Bearb. areal: 27048 m²
#           - Varighed i alt: 2301
#           - Udbytte samlet masse: 9208 kg
#           - Fugtighed: 8.81 %
#           - Tørstofindhold: 91.19 %
#
#       TASK: TSK2
#         Time: 2024-07-30 20:44:39 - 2024-07-31 12:48:54
#         Crop: RA - Raps / rybs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00002
#         Registered Properties (Totals):
#           - Bearb. areal: 39342 m²
#           - Varighed i alt: 3087
#           - Udbytte samlet masse: 11801 kg
#           - Fugtighed: 8.81 %
#           - Tørstofindhold: 91.19 %
#
#       TASK: TSK3
#         Time: 2024-07-30 20:44:39 - 2024-07-31 12:48:54
#         Crop: RA - Raps / rybs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 57855
#           - Udbytte samlet masse: 21 kg
#           - Fugtighed: 8.81 %
#           - Tørstofindhold: 91.19 %
#
#     FIELD: 022-0, Lidia
#       TASK: TSK52
#         Time: 2024-07-30 15:11:53 - 2024-07-31 13:13:05
#         Crop: RA - Raps / rybs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00034
#         Registered Properties (Totals):
#           - Bearb. areal: 346443 m²
#           - Varighed i alt: 35891
#           - Udbytte samlet masse: 111085 kg
#           - Fugtighed: 8.63 %
#           - Tørstofindhold: 91.37 %
#
#       TASK: TSK53
#         Time: 2024-07-30 15:11:53 - 2024-07-31 13:13:05
#         Crop: RA - Raps / rybs
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00035
#         Registered Properties (Totals):
#           - Bearb. areal: 262487 m²
#           - Varighed i alt: 31486
#           - Udbytte samlet masse: 97742 kg
#           - Fugtighed: 8.63 %
#           - Tørstofindhold: 91.37 %
#
#       TASK: TSK54
#         Time: 2024-07-30 15:11:53 - 2024-07-31 13:13:05
#         Crop: RA - Raps / rybs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 79272
#           - Udbytte samlet masse: 209 kg
#           - Fugtighed: 8.63 %
#           - Tørstofindhold: 91.37 %
#
#     FIELD: 023-0, Veronica 1
#       TASK: TSK60
#         Time: 2024-08-13 17:09:59 - 2024-08-13 18:34:24
#         Crop: HV - Hvede
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00039
#         Registered Properties (Totals):
#           - Bearb. areal: 38813 m²
#           - Varighed i alt: 3135
#           - Udbytte samlet masse: 22199 kg
#           - Fugtighed: 12.64 %
#           - Tørstofindhold: 87.36 %
#
#       TASK: TSK61
#         Time: 2024-08-13 17:09:59 - 2024-08-13 18:34:24
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00040
#         Registered Properties (Totals):
#           - Bearb. areal: 39685 m²
#           - Varighed i alt: 3155
#           - Udbytte samlet masse: 21957 kg
#           - Fugtighed: 12.64 %
#           - Tørstofindhold: 87.36 %
#
#       TASK: TSK62
#         Time: 2024-08-13 17:09:59 - 2024-08-13 18:34:24
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 5065
#           - Udbytte samlet masse: 44 kg
#           - Fugtighed: 12.64 %
#           - Tørstofindhold: 87.36 %
#
#     FIELD: 023-2, Veronica 2
#       TASK: TSK69
#         Time: 2024-08-13 17:16:44 - 2024-08-13 17:52:39
#         Crop: HV - Hvede
# ...
#           - Fugtighed: 13.75 %
#           - Tørstofindhold: 86.25 %
#
#       TASK: TSK80
#         Time: 2025-08-08 18:42:35 - 2025-08-10 14:38:48
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 158173
#           - Udbytte samlet masse: 193 kg
#           - Fugtighed: 13.75 %
#           - Tørstofindhold: 86.25 %
#
#       TASK: TSK81
#         Time: 2025-08-09 16:56:45 - 2025-08-09 17:31:00
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00053
#         Registered Properties (Totals):
#           - Bearb. areal: 22227 m²
#           - Varighed i alt: 2055
#           - Udbytte samlet masse: 17156 kg
#           - Fugtighed: 13.03 %
#           - Tørstofindhold: 86.97 %
#
#       TASK: TSK82
#         Time: 2025-08-09 16:56:45 - 2025-08-09 17:31:00
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00054
#         Registered Properties (Totals):
#           - Bearb. areal: 18991 m²
#           - Varighed i alt: 1937
#           - Udbytte samlet masse: 12525 kg
#           - Fugtighed: 13.03 %
#           - Tørstofindhold: 86.97 %
#
#       TASK: TSK83
#         Time: 2025-08-09 16:56:45 - 2025-08-09 17:31:00
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 2055
#           - Udbytte samlet masse: 30 kg
#           - Fugtighed: 13.03 %
#           - Tørstofindhold: 86.97 %
#
#       TASK: TSK99
#         Time: 2025-08-08 17:35:45 - 2025-08-08 18:01:05
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00065
#         Registered Properties (Totals):
#           - Bearb. areal: 9075 m²
#           - Varighed i alt: 700
#           - Udbytte samlet masse: 5164 kg
#           - Fugtighed: 14.55 %
#           - Tørstofindhold: 85.45 %
#
#       TASK: TSK100
#         Time: 2025-08-08 17:35:45 - 2025-08-08 18:01:05
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00066
#         Registered Properties (Totals):
#           - Bearb. areal: 14949 m²
#           - Varighed i alt: 1520
#           - Udbytte samlet masse: 9888 kg
#           - Fugtighed: 14.55 %
#           - Tørstofindhold: 85.45 %
#
#       TASK: TSK101
#         Time: 2025-08-08 17:35:45 - 2025-08-08 18:01:05
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 1520
#           - Udbytte samlet masse: 15 kg
#           - Fugtighed: 14.55 %
#           - Tørstofindhold: 85.45 %
#
#       TASK: TSK118
#         Time: 2025-07-19 12:58:51 - 2025-07-19 21:21:31
#         Crop: RG - Rajgræs
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00077
#         Registered Properties (Totals):
#           - Bearb. areal: 87022 m²
#           - Varighed i alt: 29635
#           - Udbytte samlet masse: 12697 kg
#           - Fugtighed: 15.94 %
#           - Tørstofindhold: 84.06 %
#
#       TASK: TSK119
#         Time: 2025-07-19 12:58:51 - 2025-07-19 21:21:31
#         Crop: RG - Rajgræs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00078
#         Registered Properties (Totals):
#           - Bearb. areal: 82332 m²
#           - Varighed i alt: 29210
#           - Udbytte samlet masse: 8856 kg
#           - Fugtighed: 15.94 %
#           - Tørstofindhold: 84.06 %
#
#       TASK: TSK120
#         Time: 2025-07-19 12:58:51 - 2025-07-19 21:21:31
#         Crop: RG - Rajgræs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 30160
#           - Udbytte samlet masse: 22 kg
#           - Fugtighed: 15.94 %
#           - Tørstofindhold: 84.06 %
#
#       TASK: TSK125
#         Time: 2025-08-10 13:00:07 - 2025-08-10 14:14:48
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00082
#         Registered Properties (Totals):
#           - Bearb. areal: 19037 m²
#           - Varighed i alt: 2115
#           - Udbytte samlet masse: 15864 kg
#           - Fugtighed: 13.91 %
#           - Tørstofindhold: 86.09 %
#
#       TASK: TSK126
#         Time: 2025-08-10 13:00:07 - 2025-08-10 14:14:48
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00083
#         Registered Properties (Totals):
#           - Bearb. areal: 49515 m²
#           - Varighed i alt: 4040
#           - Udbytte samlet masse: 45893 kg
#           - Fugtighed: 13.91 %
#           - Tørstofindhold: 86.09 %
#
#       TASK: TSK127
#         Time: 2025-08-10 13:00:07 - 2025-08-10 14:14:48
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 4481
#           - Udbytte samlet masse: 62 kg
#           - Fugtighed: 13.91 %
#           - Tørstofindhold: 86.09 %
#
#       TASK: TSK138
#         Time: 2025-08-05 20:58:16 - 2025-08-06 07:44:27
#         Crop: RA - Raps / rybs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00090
#         Registered Properties (Totals):
#           - Bearb. areal: 38672 m²
#           - Varighed i alt: 4230
#           - Udbytte samlet masse: 10098 kg
#           - Fugtighed: 9.58 %
#           - Tørstofindhold: 90.42 %
#
#       TASK: TSK139
#         Time: 2025-08-05 20:58:16 - 2025-08-06 07:44:27
#         Crop: RA - Raps / rybs
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00091
#         Registered Properties (Totals):
#           - Bearb. areal: 32460 m²
#           - Varighed i alt: 3395
#           - Udbytte samlet masse: 10613 kg
#           - Fugtighed: 9.58 %
#           - Tørstofindhold: 90.42 %
#
#       TASK: TSK140
#         Time: 2025-08-05 20:58:16 - 2025-08-06 07:44:27
#         Crop: RA - Raps / rybs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 38771
#           - Udbytte samlet masse: 21 kg
#           - Fugtighed: 9.58 %
#           - Tørstofindhold: 90.42 %
#
#       TASK: TSK143
#         Time: 2025-08-08 11:44:35 - 2025-08-08 16:12:30
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00093
#         Registered Properties (Totals):
#           - Bearb. areal: 100757 m²
#           - Varighed i alt: 8750
#           - Udbytte samlet masse: 82604 kg
#           - Fugtighed: 14.83 %
#           - Tørstofindhold: 85.17 %
#
#       TASK: TSK144
#         Time: 2025-08-08 11:44:35 - 2025-08-08 16:12:30
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00094
#         Registered Properties (Totals):
#           - Bearb. areal: 96379 m²
#           - Varighed i alt: 9120
#           - Udbytte samlet masse: 75994 kg
#           - Fugtighed: 14.83 %
#           - Tørstofindhold: 85.17 %
#
#       TASK: TSK145
#         Time: 2025-08-08 11:44:35 - 2025-08-08 16:12:30
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 16075
#           - Udbytte samlet masse: 159 kg
#           - Fugtighed: 14.83 %
#           - Tørstofindhold: 85.17 %
#
#       TASK: TSK152
#         Time: 2025-08-05 19:37:48 - 2025-08-08 16:22:56
#         Crop: RA - Raps / rybs
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00099
#         Registered Properties (Totals):
#           - Bearb. areal: 29442 m²
#           - Varighed i alt: 5348
#           - Udbytte samlet masse: 12608 kg
#           - Fugtighed: 10.28 %
#           - Tørstofindhold: 89.72 %
#
#       TASK: TSK153
#         Time: 2025-08-05 19:37:48 - 2025-08-08 16:22:56
#         Crop: RA - Raps / rybs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00100
#         Registered Properties (Totals):
#           - Bearb. areal: 26920 m²
#           - Varighed i alt: 4653
#           - Udbytte samlet masse: 10122 kg
#           - Fugtighed: 10.28 %
#           - Tørstofindhold: 89.72 %
#
#       TASK: TSK154
#         Time: 2025-08-05 19:37:48 - 2025-08-08 16:22:56
#         Crop: RA - Raps / rybs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 247508
#           - Udbytte samlet masse: 23 kg
#           - Fugtighed: 10.28 %
#           - Tørstofindhold: 89.72 %
#
#       TASK: TSK155
#         Time: 2025-08-08 09:53:20 - 2025-08-08 11:41:25
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00101
#         Registered Properties (Totals):
#           - Bearb. areal: 56252 m²
#           - Varighed i alt: 5270
#           - Udbytte samlet masse: 48329 kg
#           - Fugtighed: 15.65 %
#           - Tørstofindhold: 84.35 %
#
#       TASK: TSK156
#         Time: 2025-08-08 09:53:20 - 2025-08-08 11:41:25
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00102
#         Registered Properties (Totals):
#           - Bearb. areal: 53014 m²
#           - Varighed i alt: 5555
#           - Udbytte samlet masse: 40579 kg
#           - Fugtighed: 15.65 %
#           - Tørstofindhold: 84.35 %
#
#       TASK: TSK157
#         Time: 2025-08-08 09:53:20 - 2025-08-08 11:41:25
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 6485
#           - Udbytte samlet masse: 89 kg
#           - Fugtighed: 15.65 %
#           - Tørstofindhold: 84.35 %
#
#       TASK: TSK158
#         Time: 2025-08-09 15:48:40 - 2025-08-09 21:51:32
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00103
#         Registered Properties (Totals):
#           - Bearb. areal: 211989 m²
#           - Varighed i alt: 15655
#           - Udbytte samlet masse: 147569 kg
#           - Fugtighed: 13.16 %
#           - Tørstofindhold: 86.84 %
#
#       TASK: TSK159
#         Time: 2025-08-09 15:48:40 - 2025-08-09 21:51:32
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00104
#         Registered Properties (Totals):
#           - Bearb. areal: 167916 m²
#           - Varighed i alt: 15149
#           - Udbytte samlet masse: 106862 kg
#           - Fugtighed: 13.16 %
#           - Tørstofindhold: 86.84 %
#
#       TASK: TSK160
#         Time: 2025-08-09 15:48:40 - 2025-08-09 21:51:32
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 21772
#           - Udbytte samlet masse: 254 kg
#           - Fugtighed: 13.16 %
#           - Tørstofindhold: 86.84 %
#
#       TASK: TSK161
#         Time: 2025-08-09 16:00:25 - 2025-08-09 17:33:05
#         Crop: HV - Hvede
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00105
#         Registered Properties (Totals):
#           - Bearb. areal: 39944 m²
#           - Varighed i alt: 3400
#           - Udbytte samlet masse: 29045 kg
#           - Fugtighed: 13.49 %
#           - Tørstofindhold: 86.51 %
#
#       TASK: TSK162
#         Time: 2025-08-09 16:00:25 - 2025-08-09 17:33:05
#         Crop: HV - Hvede
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00106
#         Registered Properties (Totals):
#           - Bearb. areal: 38807 m²
#           - Varighed i alt: 3550
#           - Udbytte samlet masse: 22723 kg
#           - Fugtighed: 13.49 %
#           - Tørstofindhold: 86.51 %
#
#       TASK: TSK163
#         Time: 2025-08-09 16:00:25 - 2025-08-09 17:33:05
#         Crop: HV - Hvede
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 5560
#           - Udbytte samlet masse: 52 kg
#           - Fugtighed: 13.49 %
#           - Tørstofindhold: 86.51 %
#
#       TASK: TSK170
#         Time: 2025-08-05 18:01:31 - 2025-08-08 16:07:45
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00111
#         Registered Properties (Totals):
#           - Bearb. areal: 83094 m²
#           - Varighed i alt: 6537
#           - Udbytte samlet masse: 66165 kg
#           - Fugtighed: 14.30 %
#           - Tørstofindhold: 85.70 %
#
#       TASK: TSK171
#         Time: 2025-08-05 18:01:31 - 2025-08-08 16:07:45
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00112
#         Registered Properties (Totals):
#           - Bearb. areal: 88062 m²
#           - Varighed i alt: 6926
#           - Udbytte samlet masse: 72429 kg
#           - Fugtighed: 14.30 %
#           - Tørstofindhold: 85.70 %
#
#       TASK: TSK172
#         Time: 2025-08-05 18:01:31 - 2025-08-08 16:07:45
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 252374
#           - Udbytte samlet masse: 139 kg
#           - Fugtighed: 14.30 %
#           - Tørstofindhold: 85.70 %
#
#       TASK: TSK193
#         Time: 2025-08-05 19:56:17 - 2025-08-08 11:45:10
#         Crop: RA - Raps / rybs
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00126
#         Registered Properties (Totals):
#           - Bearb. areal: 8683 m²
#           - Varighed i alt: 1012
#           - Udbytte samlet masse: 874 kg
#           - Fugtighed: 10.97 %
#           - Tørstofindhold: 89.03 %
#
#       TASK: TSK194
#         Time: 2025-08-05 19:56:17 - 2025-08-08 11:45:10
#         Crop: RA - Raps / rybs
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00127
#         Registered Properties (Totals):
#           - Bearb. areal: 6497 m²
#           - Varighed i alt: 1037
#           - Udbytte samlet masse: 1410 kg
#           - Fugtighed: 10.97 %
#           - Tørstofindhold: 89.03 %
#
#       TASK: TSK195
#         Time: 2025-08-05 19:56:17 - 2025-08-08 11:45:10
#         Crop: RA - Raps / rybs
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 229733
#           - Udbytte samlet masse: 2 kg
#           - Fugtighed: 10.97 %
#           - Tørstofindhold: 89.03 %
#
#       TASK: TSK196
#         Time: 2025-08-08 09:40:40 - 2025-08-08 11:42:35
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00128
#         Registered Properties (Totals):
#           - Bearb. areal: 10713 m²
#           - Varighed i alt: 1781
#           - Udbytte samlet masse: 8273 kg
#           - Fugtighed: 16.65 %
#           - Tørstofindhold: 83.35 %
#
#       TASK: TSK197
#         Time: 2025-08-08 09:40:40 - 2025-08-08 11:42:35
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00129
#         Registered Properties (Totals):
#           - Bearb. areal: 13409 m²
#           - Varighed i alt: 1597
#           - Udbytte samlet masse: 11262 kg
#           - Fugtighed: 16.65 %
#           - Tørstofindhold: 83.35 %
#
#       TASK: TSK198
#         Time: 2025-08-08 09:40:40 - 2025-08-08 11:42:35
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 7315
#           - Udbytte samlet masse: 20 kg
#           - Fugtighed: 16.65 %
#           - Tørstofindhold: 83.35 %
#
#       TASK: TSK206
#         Time: 2025-08-09 10:41:45 - 2025-08-09 15:18:00
#         Crop: VB - Vårbyg
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00135
#         Registered Properties (Totals):
#           - Bearb. areal: 123280 m²
#           - Varighed i alt: 11890
#           - Udbytte samlet masse: 105466 kg
#           - Fugtighed: 15.12 %
#           - Tørstofindhold: 84.88 %
#
#       TASK: TSK207
#         Time: 2025-08-09 10:41:45 - 2025-08-09 15:18:00
#         Crop: VB - Vårbyg
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00136
#         Registered Properties (Totals):
#           - Bearb. areal: 133503 m²
#           - Varighed i alt: 11940
#           - Udbytte samlet masse: 103470 kg
#           - Fugtighed: 15.12 %
#           - Tørstofindhold: 84.88 %
#
#       TASK: TSK208
#         Time: 2025-08-09 10:41:45 - 2025-08-09 15:18:00
#         Crop: VB - Vårbyg
#         Machine: Generic Implement
#         TLG Files: None
#         Registered Properties (Totals):
#           - Varighed i alt: 16575
#           - Udbytte samlet masse: 209 kg
#           - Fugtighed: 15.12 %
#           - Tørstofindhold: 84.88 %
