# %% [markdown]
# # How to use this notebook (recommended for non-CLI users)
#
# This notebook is designed for users who prefer working interactively rather than running command-line scripts.
#
# - Step 1: Ensure you have activated the `pyagri-notebooks` environment and installed the package in editable mode (`pip install -e .`). See the top cell for environment checks.
# - Step 2: Set the `PROJECT_ROOT` variable in the **Configuration** cell if you want to use an explicit absolute path; otherwise the notebook will use the current working directory. All other data paths (inputs and outputs) are relative to `PROJECT_ROOT`.
# - Step 3: In the **Configuration** cell, confirm `INPUT_TASKDATA` (list of TaskData folders), `LEDREBORG_OUT` and `HARVEST_GEOJSON` look correct.
# - Step 4 (recommended): Run the small **Per-input API** cell for the specific input(s) you want to process — this calls the library functions directly and shows concise results inline.
# - Step 5: Use the **Advanced: Batch run** cell only if you want to process multiple inputs in one go (this runs subprocesses and is better for batch jobs, not interactive exploration).
#
# If a GeoJSON or CSV already exists, the notebook will append features or rows rather than overwrite, so you can safely run the same input multiple times for incremental exports.
#
# Tip: to quickly set `PROJECT_ROOT` to the workspace root use:
#
# ```python
# PROJECT_ROOT = Path(r"C:/dev/agri_analysis").resolve()
# ```

# %%
# 01_Raw_read
# Friendly notebook that reproduces the CLI workflows:
#  - python -m pyagri.export data/TASKDATA_2 data/ledreborg_CSV
#  - python -m pyagri.geo data/TASKDATA data/harvest_fields_s.geojson

# NOTE: This notebook is intended to be run in the `pyagri-notebooks` environment
# (or another environment with the project installed in editable mode).
# Recommended quick setup (run in a shell once):
#   micromamba activate pyagri-notebooks
#   pip install -e .
#   pip install geopandas pandas

# Section 1: Quick environment check
import sys
from pathlib import Path
import logging

logger = logging.getLogger('01_Raw_read')
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
handler.setLevel(logging.INFO)
logger.addHandler(handler)

logger.info('Python executable: %s', sys.executable)
try:
    import pyagri
    logger.info('pyagri import OK')
except Exception as e:
    logger.warning('pyagri import failed: %s', e)
# Out:
# Python executable: c:\Users\holmes\.local\share\mamba\envs\pyagri-notebooks\python.exe
# pyagri import OK

# %%
# Configuration cell — set project root, inputs and outputs here
# Set the PROJECT_ROOT to the absolute path of the folder containing the data (the previous cell set it to the folder of the notebook)
# Example explicit override (uncomment and adjust if you run the notebook from a different working directory):
PROJECT_ROOT = Path.cwd().resolve().parent

# PROJECT_ROOT = Path(r"C:/dev/agri_analysis").resolve()

DATA_DIR = PROJECT_ROOT / 'data'

# You can specify more than one TaskData folder in INPUT_TASKDATA list. These are paths relative to PROJECT_ROOT.
INPUT_TASKDATA = [
    DATA_DIR / 'TASKDATA_2',  # example input folder 1
    DATA_DIR / 'TASKDATA',  # add more as needed
]

# CSV output directory (one dir used for all inputs; files for each task will be appended)
HARVESTER_POINTS_DIR = PROJECT_ROOT / 'data' / 'ledreborg_CSV'
HARVESTER_POINTS_DIR.mkdir(parents=True, exist_ok=True)

# GeoJSON output file for task polygons (appends features if file exists)
FIELD_POLYGONS_GEOJSON = PROJECT_ROOT / 'data' / 'harvest_fields_s.geojson'

# --- Set target projected CRS for area/overlap analysis ---
# Use EPSG:25832 (ETRS89 / UTM zone 32N) for Denmark
EPSG = '25832'  # Change as needed for your region


logger.info('Project root: %s', PROJECT_ROOT)
logger.info('Configured %d input folders: %s', len(INPUT_TASKDATA), [str(p) for p in INPUT_TASKDATA])
logger.info('CSV output dir: %s', HARVESTER_POINTS_DIR)
logger.info('GeoJSON output file: %s', FIELD_POLYGONS_GEOJSON)
logger.info('Target projected CRS EPSG: %s', EPSG)
# Out:
# Project root: C:\dev\agri_analysis
# Configured 2 input folders: ['C:\\dev\\agri_analysis\\data\\TASKDATA_2', 'C:\\dev\\agri_analysis\\data\\TASKDATA']
# CSV output dir: C:\dev\agri_analysis\data\ledreborg_CSV
# GeoJSON output file: C:\dev\agri_analysis\data\harvest_fields_s.geojson
# Target projected CRS EPSG: 25832

# %% [markdown]
# ## Loding binary data
# The following cell loads the data form the XML and binary data and exports it to CSV and GeoJSON for futher analasis. If you alredy have converted the data and only want to validate the data skip the following cell

# %%
# Per-input API example 
try:
    from pyagri import export as export_mod
    from pyagri import geo as geo_mod
    for src in INPUT_TASKDATA:
        srcp = Path(src)
        if not srcp.exists():
            logger.warning('Skipping missing input: %s', srcp)
            continue
        logger.info('Exporting (API) for: %s', srcp)
        written = export_mod.export_taskdata(str(srcp), str(HARVESTER_POINTS_DIR))
        logger.info('Wrote CSV files: %s', written)

        logger.info('Extracting GeoJSON (API) for: %s', srcp)
        rc = geo_mod.extract_taskdata_to_geojson(str(srcp), str(FIELD_POLYGONS_GEOJSON))
        logger.info('Geo extraction returned: %s (%s)', rc, 'success' if rc == 0 else 'error')
except Exception as e:
    logger.exception('Per-input API example failed: %s', e)
# Out:
# Exporting (API) for: C:\dev\agri_analysis\data\TASKDATA_2
# Wrote CSV files: ['C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\021-0_ Monica.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\021-0_ Monica.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\021-0_ Monica.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-0_ Stendyssegård.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-0_ Stendyssegård.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-0_ Stendyssegård.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\037-0_ Bispegård øst.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\037-0_ Bispegård øst.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\037-0_ Bispegård øst.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\014-0_ Dellingemølle.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\014-0_ Dellingemølle.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\024-0_ Silvia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\024-0_ Silvia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\013-0_ Hulegaard b_.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\013-0_ Hulegaard b_.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\013-0_ Hulegaard b_.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-2_ Veronica 2.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-2_ Veronica 2.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-2_ Veronica 2.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\035-0_ Bispegård mark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\035-0_ Bispegård mark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\035-0_ Bispegård mark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\002-0_ St_Amalienborg_Litgoth.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\002-0_ St_Amalienborg_Litgoth.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\022-0_ Lidia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\022-0_ Lidia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\011-0_ Akselbæk.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\011-0_ Akselbæk.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\011-0_ Akselbæk.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\015-0_ Hulemølle.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\015-0_ Hulemølle.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\015-0_ Hulemølle.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\021-0_ Monica.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\021-0_ Monica.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-2_ Stendyssegård Højre.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-2_ Stendyssegård Højre.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-0_ Stendyssegård.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-0_ Stendyssegård.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-0_ Stendyssegård.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-0_ Veronica 1.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-0_ Veronica 1.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-0_ Veronica 1.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\012-0_ Hulegaardsmark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\012-0_ Hulegaardsmark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\012-0_ Hulegaardsmark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-0.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-0.csv']
# Extracting GeoJSON (API) for: C:\dev\agri_analysis\data\TASKDATA_2
# Geo extraction returned: 0
# Exporting (API) for: C:\dev\agri_analysis\data\TASKDATA
# Wrote CSV files: ['C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\021-0_ Monica.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\021-0_ Monica.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\021-0_ Monica.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\022-0_ Lidia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\022-0_ Lidia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\022-0_ Lidia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\022-0_ Lidia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-2_ Stendyssegård Højre.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-2_ Stendyssegård Højre.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\011-0_ Akselbæk.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\011-0_ Akselbæk.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\011-0_ Akselbæk.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\B025-1_ Brak - C_T Syd.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\B025-1_ Brak - C_T Syd.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-2_ Veronica 2.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-2_ Veronica 2.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-2_ Veronica 2.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\040-0_ Holmegård syd.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\040-0_ Holmegård syd.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\040-0_ Holmegård syd.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\011-0_ Akselbæk.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\011-0_ Akselbæk.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\012-0_ Hulegaardsmark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\012-0_ Hulegaardsmark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\012-0_ Hulegaardsmark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\015-0_ Hulemølle.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\015-0_ Hulemølle.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\015-0_ Hulemølle.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\035-0_ Bispegård mark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\035-0_ Bispegård mark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\035-0_ Bispegård mark.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\Import.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\014-0_ Dellingemølle.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\014-0_ Dellingemølle.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-0_ Veronica 1.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-0_ Veronica 1.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\023-0_ Veronica 1.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\039-0_ Holmegård nord.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\039-0_ Holmegård nord.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\039-0_ Holmegård nord.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\022-0_ Lidia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\022-0_ Lidia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\022-0_ Lidia.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-2_ Stendyssegård Højre.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-2_ Stendyssegård Højre.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\016-2_ Stendyssegård Højre.csv', 'C:\\dev\\agri_analysis\\data\\ledreborg_CSV\\022-0_ Lidia.csv', 'C:\\dev\\agr ...
# Extracting GeoJSON (API) for: C:\dev\agri_analysis\data\TASKDATA
# Geo extraction returned: 0

# %%
# --- Display enhanced TASKDATA.XML report (with crop, TLG, sensors) ---
from pyagri.taskdata_report import taskdata_report

xml_path = PROJECT_ROOT / 'data' / 'taskdata' / 'TASKDATA.XML'
taskdata_report(xml_path)
# Out:
# Year: 2022
#   Field: 002-0, St.Amalienborg/Litgoth
#     Task TSK189: Product=PFD54 Device=DVC1 Details=4
#       Start: 2022-08-04T18:06:44.000+02:00 End: 2022-08-13T22:30:35.000+02:00
#     Task TSK190: Product=PFD54 Device=DVC4 Details=4
#       Start: 2022-08-04T18:06:44.000+02:00 End: 2022-08-13T22:30:35.000+02:00
#     Task TSK191: Product=PFD54 Device=DVC3 Details=4
#       Start: 2022-08-04T18:06:44.000+02:00 End: 2022-08-13T22:30:35.000+02:00
#     Task TSK192: Product=PFD54 Device=DVC6 Details=4
#       Start: 2022-08-04T18:06:44.000+02:00 End: 2022-08-13T22:30:35.000+02:00
#   Field: 010-0, Møllemark
#     Task TSK182: Product=PFD52 Device=DVC1 Details=4
#       Start: 2022-08-13T14:32:41.000+02:00 End: 2022-08-13T18:46:03.000+02:00
#     Task TSK183: Product=PFD52 Device=DVC6 Details=4
#       Start: 2022-08-13T14:32:41.000+02:00 End: 2022-08-13T18:46:03.000+02:00
#   Field: 011-0, Akselbæk
#     Task TSK27: Product=PFD20 Device=DVC1 Details=4
#       Start: 2022-08-13T11:58:22.000+02:00 End: 2022-08-13T14:28:00.000+02:00
#     Task TSK28: Product=PFD20 Device=DVC6 Details=4
#       Start: 2022-08-13T11:58:22.000+02:00 End: 2022-08-13T14:28:00.000+02:00
#   Field: 012-0, Hulegaardsmark
#     Task TSK130: Product=PFD55 Device=DVC1 Details=4
#       Start: 2022-08-12T18:26:37.000+02:00 End: 2022-08-13T11:58:06.000+02:00
#     Task TSK131: Product=PFD55 Device=DVC6 Details=4
#       Start: 2022-08-12T18:26:37.000+02:00 End: 2022-08-13T11:58:06.000+02:00
#   Field: 013-0, Hulegaard b.
#     Task TSK87: Product=PFD5 Device=DVC1 Details=4
#       Start: 2022-08-12T17:00:52.000+02:00 End: 2022-08-12T18:25:56.000+02:00
#     Task TSK88: Product=PFD5 Device=DVC6 Details=4
#       Start: 2022-08-12T17:00:52.000+02:00 End: 2022-08-12T18:25:56.000+02:00
#   Field: 015-0, Hulemølle
#     Task TSK96: Product=PFD3 Device=DVC4 Details=4
#       Start: 2022-08-04T11:34:10.000+02:00 End: 2022-08-04T17:45:51.000+02:00
#     Task TSK97: Product=PFD3 Device=DVC3 Details=4
#       Start: 2022-08-04T11:34:10.000+02:00 End: 2022-08-04T17:45:51.000+02:00
#     Task TSK98: Product=PFD3 Device=DVC6 Details=4
#       Start: 2022-08-04T11:34:10.000+02:00 End: 2022-08-04T17:45:51.000+02:00
#   Field: 016-1, Stendyssegård Venstr
#     Task TSK209: Product=PFD30 Device=DVC3 Details=4
#       Start: 2022-08-04T11:04:48.000+02:00 End: 2022-08-04T11:51:10.000+02:00
#     Task TSK210: Product=PFD30 Device=DVC6 Details=4
#       Start: 2022-08-04T11:04:48.000+02:00 End: 2022-08-04T11:51:10.000+02:00
#   Field: 016-2, Stendyssegård Højre
#     Task TSK14: Product=PFD23 Device=DVC3 Details=4
#       Start: 2022-08-04T10:34:28.000+02:00 End: 2022-08-04T11:04:34.000+02:00
#     Task TSK15: Product=PFD23 Device=DVC6 Details=4
#       Start: 2022-08-04T10:34:28.000+02:00 End: 2022-08-04T11:04:34.000+02:00
#   Field: 022-0, Lidia
#     Task TSK58: Product=PFD33 Device=DVC2 Details=4
#       Start: 2022-08-14T18:59:39.000+02:00 End: 2022-08-15T20:58:38.000+02:00
#     Task TSK59: Product=PFD33 Device=DVC6 Details=4
#       Start: 2022-08-14T18:59:39.000+02:00 End: 2022-08-15T20:58:38.000+02:00
#   Field: 035-0, Bispegård mark
#     Task TSK38: Product=PFD41 Device=DVC4 Details=4
#       Start: 2022-08-04T10:54:04.000+02:00 End: 2022-08-04T17:44:13.000+02:00
#     Task TSK39: Product=PFD41 Device=DVC3 Details=4
#       Start: 2022-08-04T10:54:04.000+02:00 End: 2022-08-04T17:44:13.000+02:00
#     Task TSK40: Product=PFD41 Device=DVC6 Details=4
#       Start: 2022-08-04T10:54:04.000+02:00 End: 2022-08-04T17:44:13.000+02:00
#
# Year: 2023
#   Field: 002-0, St.Amalienborg/Litgoth
#     Task TSK167: Product=PFD56 Device=DVC2 Details=4
#       Start: 2023-08-15T20:58:16.000+02:00 End: 2023-08-16T11:20:01.000+02:00
#     Task TSK168: Product=PFD56 Device=DVC1 Details=4
#       Start: 2023-08-15T20:58:16.000+02:00 End: 2023-08-16T11:20:01.000+02:00
#     Task TSK169: Product=PFD56 Device=DVC6 Details=4
#       Start: 2023-08-15T20:58:16.000+02:00 End: 2023-08-16T11:20:01.000+02:00
#   Field: 010-0, Møllemark
#     Task TSK215: Product=PFD61 Device=DVC2 Details=4
#       Start: 2023-08-16T11:34:57.000+02:00 End: 2023-08-16T14:57:34.000+02:00
#     Task TSK216: Product=PFD61 Device=DVC1 Details=4
#       Start: 2023-08-16T11:34:57.000+02:00 End: 2023-08-16T14:57:34.000+02:00
#     Task TSK217: Product=PFD61 Device=DVC6 Details=4
#       Start: 2023-08-16T11:34:57.000+02:00 End: 2023-08-16T14:57:34.000+02:00
#   Field: 011-0, Akselbæk
#     Task TSK16: Product=PFD11 Device=DVC1 Details=4
#       Start: 2023-08-16T17:51:04.000+02:00 End: 2023-08-16T19:02:29.000+02:00
#     Task TSK17: Product=PFD11 Device=DVC2 Details=4
#       Start: 2023-08-16T17:51:04.000+02:00 End: 2023-08-16T19:02:29.000+02:00
#     Task TSK18: Product=PFD11 Device=DVC6 Details=4
#       Start: 2023-08-16T17:51:04.000+02:00 End: 2023-08-16T19:02:29.000+02:00
#   Field: 012-0, Hulegaardsmark
#     Task TSK135: Product=PFD49 Device=DVC2 Details=4
#       Start: 2023-08-06T16:42:16.000+02:00 End: 2023-08-16T21:56:33.000+02:00
#     Task TSK136: Product=PFD49 Device=DVC1 Details=4
#       Start: 2023-08-06T16:42:16.000+02:00 End: 2023-08-16T21:56:33.000+02:00
#     Task TSK137: Product=PFD49 Device=DVC6 Details=4
#       Start: 2023-08-06T16:42:16.000+02:00 End: 2023-08-16T21:56:33.000+02:00
#   Field: 013-0, Hulegaard b.
#     Task TSK164: Product=PFD22 Device=DVC2 Details=4
#       Start: 2023-08-06T15:46:56.000+02:00 End: 2023-08-16T21:44:43.000+02:00
#     Task TSK165: Product=PFD22 Device=DVC1 Details=4
#       Start: 2023-08-06T15:46:56.000+02:00 End: 2023-08-16T21:44:43.000+02:00
#     Task TSK166: Product=PFD22 Device=DVC6 Details=4
#       Start: 2023-08-06T15:46:56.000+02:00 End: 2023-08-16T21:44:43.000+02:00
#   Field: 014-0, Dellingemølle
#     Task TSK44: Product=PFD16 Device=DVC1 Details=4
#       Start: 2023-08-16T14:16:30.000+02:00 End: 2023-08-16T16:58:20.000+02:00
#     Task TSK45: Product=PFD16 Device=DVC6 Details=4
#       Start: 2023-08-16T14:16:30.000+02:00 End: 2023-08-16T16:58:20.000+02:00
#   Field: 015-0, Hulemølle
#     Task TSK32: Product=PFD12 Device=DVC2 Details=4
#       Start: 2023-08-15T10:28:54.000+02:00 End: 2023-08-15T13:21:40.000+02:00
#     Task TSK33: Product=PFD12 Device=DVC1 Details=4
#       Start: 2023-08-15T10:28:54.000+02:00 End: 2023-08-15T13:21:40.000+02:00
#     Task TSK34: Product=PFD12 Device=DVC6 Details=4
#       Start: 2023-08-15T10:28:54.000+02:00 End: 2023-08-15T13:21:40.000+02:00
#   Field: 016-0, Stendyssegård
#     Task TSK146: Product=PFD36 Device=DVC2 Details=4
#       Start: 2023-08-14T19:52:36.000+02:00 End: 2023-08-14T21:06:11.000+02:00
#     Task TSK147: Product=PFD36 Device=DVC1 Details=4
#       Start: 2023-08-14T19:52:36.000+02:00 End: 2023-08-14T21:06:11.000+02:00
#     Task TSK148: Product=PFD36 Device=DVC6 Details=4
#       Start: 2023-08-14T19:52:36.000+02:00 End: 2023-08-14T21:06:11.000+02:00
#   Field: 016-1, Stendyssegård Venstr
#     Task TSK149: Product=PFD57 Device=DVC2 Details=4
#       Start: 2023-08-14T21:18:21.000+02:00 End: 2023-08-15T10:36:10.000+02:00
#     Task TSK150: Product=PFD57 Device=DVC1 Details=4
#       Start: 2023-08-14T21:18:21.000+02:00 End: 2023-08-15T10:36:10.000+02:00
#     Task TSK151: Product=PFD57 Device=DVC6 Details=4
#       Start: 2023-08-14T21:18:21.000+02:00 End: 2023-08-15T10:36:10.000+02:00
#   Field: 016-2, Stendyssegård Højre
#     Task TSK55: Product=PFD9 Device=DVC2 Details=4
#       Start: 2023-08-14T21:08:47.000+02:00 End: 2023-08-15T10:37:50.000+02:00
#     Task TSK56: Product=PFD9 Device=DVC1 Details=4
#       Start: 2023-08-14T21:08:47.000+02:00 End: 2023-08-15T10:37:50.000+02:00
#     Task TSK57: Product=PFD9 Device=DVC6 Details=4
#       Start: 2023-08-14T21:08:47.000+02:00 End: 2023-08-15T10:37:50.000+02:00
#   Field: 021-0, Monica
#     Task TSK116: Product=PFD71 Device=DVC2 Details=4
#       Start: 2023-08-14T10:33:46.000+02:00 End: 2023-08-14T12:42:26.000+02:00
#     Task TSK117: Product=PFD71 Device=DVC6 Details=4
#       Start: 2023-08-14T10:33:46.000+02:00 End: 2023-08-14T12:42:26.000+02:00
#   Field: 022-0, Lidia
#     Task TSK10: Product=PFD19 Device=DVC1 Details=4
#       Start: 2023-07-18T13:55:19.000+02:00 End: 2023-07-19T17:04:02.000+02:00
#     Task TSK11: Product=PFD19 Device=DVC2 Details=4
#       Start: 2023-07-18T13:55:19.000+02:00 End: 2023-07-19T17:04:02.000+02:00
#     Task TSK12: Product=PFD19 Device=DVC3 Details=4
#       Start: 2023-07-18T13:55:19.000+02:00 End: 2023-07-19T17:04:02.000+02:00
#     Task TSK13: Product=PFD19 Device=DVC6 Details=4
#       Start: 2023-07-18T13:55:19.000+02:00 End: 2023-07-19T17:04:02.000+02:00
#   Field: 023-0, Veronica 1
#     Task TSK46: Product=PFD31 Device=DVC2 Details=4
#       Start: 2023-08-06T11:45:32.000+02:00 End: 2023-08-06T13:07:43.000+02:00
#     Task TSK47: Product=PFD31 Device=DVC1 Details=4
#       Start: 2023-08-06T11:45:32.000+02:00 End: 2023-08-06T13:07:43.000+02:00
#     Task TSK48: Product=PFD31 Device=DVC6 Details=4
#       Start: 2023-08-06T11:45:32.000+02:00 End: 2023-08-06T13:07:43.000+02:00
#   Field: 023-2, Veronica 2
#     Task TSK21: Product=PFD66 Device=DVC1 Details=4
#       Start: 2023-08-06T12:00:03.000+02:00 End: 2023-08-06T12:29:10.000+02:00
#     Task TSK22: Product=PFD66 Device=DVC2 Details=4
#       Start: 2023-08-06T12:00:03.000+02:00 End: 2023-08-06T12:29:10.000+02:00
#     Task TSK23: Product=PFD66 Device=DVC6 Details=4
#       Start: 2023-08-06T12:00:03.000+02:00 End: 2023-08-06T12:29:10.000+02:00
#   Field: 024-0, Silvia
#     Task TSK93: Product=PFD70 Device=DVC2 Details=4
#       Start: 2023-08-14T12:46:41.000+02:00 End: 2023-08-14T17:08:41.000+02:00
#     Task TSK94: Product=PFD70 Device=DVC1 Details=4
#       Start: 2023-08-14T12:46:41.000+02:00 End: 2023-08-14T17:08:41.000+02:00
#     Task TSK95: Product=PFD70 Device=DVC6 Details=4
#       Start: 2023-08-14T12:46:41.000+02:00 End: 2023-08-14T17:08:41.000+02:00
#   Field: 025-0, Camilla/Tatiana
#     Task TSK104: Product=PFD48 Device=DVC2 Details=4
#       Start: 2023-08-06T09:54:32.000+02:00 End: 2023-08-16T17:18:50.000+02:00
#     Task TSK105: Product=PFD48 Device=DVC1 Details=4
#       Start: 2023-08-06T09:54:32.000+02:00 End: 2023-08-16T17:18:50.000+02:00
#     Task TSK106: Product=PFD48 Device=DVC6 Details=4
#       Start: 2023-08-06T09:54:32.000+02:00 End: 2023-08-16T17:18:50.000+02:00
#   Field: 035-0, Bispegård mark
#     Task TSK84: Product=PFD63 Device=DVC1 Details=4
#       Start: 2023-08-15T13:20:29.000+02:00 End: 2023-08-15T20:31:11.000+02:00
#     Task TSK85: Product=PFD63 Device=DVC2 Details=4
#       Start: 2023-08-15T13:20:29.000+02:00 End: 2023-08-15T20:31:11.000+02:00
#     Task TSK86: Product=PFD63 Device=DVC6 Details=4
#       Start: 2023-08-15T13:20:29.000+02:00 End: 2023-08-15T20:31:11.000+02:00
#   Field: 036-0, Bispegård vest
#     Task TSK109: Product=PFD46 Device=DVC1 Details=4
#       Start: 2023-08-14T16:50:39.000+02:00 End: 2023-08-14T19:49:01.000+02:00
#     Task TSK110: Product=PFD46 Device=DVC2 Details=4
#       Start: 2023-08-14T16:50:39.000+02:00 End: 2023-08-14T19:49:01.000+02:00
#     Task TSK111: Product=PFD46 Device=DVC6 Details=4
#       Start: 2023-08-14T16:50:39.000+02:00 End: 2023-08-14T19:49:01.000+02:00
#   Field: 037-0, Bispegård øst
#     Task TSK107: Product=PFD32 Device=DVC2 Details=4
#       Start: 2023-08-14T19:03:31.000+02:00 End: 2023-08-14T19:40:01.000+02:00
#     Task TSK108: Product=PFD32 Device=DVC6 Details=4
#       Start: 2023-08-14T19:03:31.000+02:00 End: 2023-08-14T19:40:01.000+02:00
#   Field: B011-1, Brak - Akselbæk nord
#     Task TSK173: Product=PFD34 Device=DVC1 Details=4
#       Start: 2023-08-16T18:04:04.000+02:00 End: 2023-08-16T18:07:25.000+02:00
#     Task TSK174: Product=PFD34 Device=DVC6 Details=4
#       Start: 2023-08-16T18:04:04.000+02:00 End: 2023-08-16T18:07:25.000+02:00
#   Field: B025-1, Brak - C/T Syd
#     Task TSK19: Product=PFD45 Device=DVC1 Details=4
#       Start: 2023-08-06T11:57:38.000+02:00 End: 2023-08-06T11:59:48.000+02:00
#     Task TSK20: Product=PFD45 Device=DVC6 Details=4
#       Start: 2023-08-06T11:57:38.000+02:00 End: 2023-08-06T11:59:48.000+02:00
#   Field: M025-6
#     Task TSK128: Product=PFD25 Device=DVC1 Details=4
#       Start: 2023-08-06T10:10:28.000+02:00 End: 2023-08-06T10:11:53.000+02:00
#     Task TSK129: Product=PFD25 Device=DVC6 Details=4
#       Start: 2023-08-06T10:10:28.000+02:00 End: 2023-08-06T10:11:53.000+02:00
#
# Year: 2024
#   Field: 002-0, St.Amalienborg
#     Task TSK132: Product=PFD10 Device=DVC2 Details=4
#       Start: 2024-08-12T15:55:05.000+02:00 End: 2024-08-12T21:27:17.000+02:00
#     Task TSK133: Product=PFD10 Device=DVC3 Details=4
#       Start: 2024-08-12T15:55:05.000+02:00 End: 2024-08-12T21:27:17.000+02:00
#     Task TSK134: Product=PFD10 Device=DVC6 Details=4
#       Start: 2024-08-12T15:55:05.000+02:00 End: 2024-08-12T21:27:17.000+02:00
#   Field: 010-0, Møllemark
#     Task TSK63: Product=PFD17 Device=DVC2 Details=4
#       Start: 2024-08-13T08:45:23.000+02:00 End: 2024-08-13T12:19:14.000+02:00
#     Task TSK64: Product=PFD17 Device=DVC3 Details=4
#       Start: 2024-08-13T08:45:23.000+02:00 End: 2024-08-13T12:19:14.000+02:00
#     Task TSK65: Product=PFD17 Device=DVC6 Details=4
#       Start: 2024-08-13T08:45:23.000+02:00 End: 2024-08-13T12:19:14.000+02:00
#   Field: 011-0, Akselbæk
#     Task TSK186: Product=PFD27 Device=DVC2 Details=4
#       Start: 2024-08-12T12:08:05.000+02:00 End: 2024-08-12T14:05:27.000+02:00
#     Task TSK187: Product=PFD27 Device=DVC3 Details=4
#       Start: 2024-08-12T12:08:05.000+02:00 End: 2024-08-12T14:05:27.000+02:00
#     Task TSK188: Product=PFD27 Device=DVC6 Details=4
#       Start: 2024-08-12T12:08:05.000+02:00 End: 2024-08-12T14:05:27.000+02:00
#   Field: 012-0, Hulegaardsmark
#     Task TSK29: Product=PFD29 Device=DVC2 Details=4
#       Start: 2024-08-11T19:54:05.000+02:00 End: 2024-08-12T14:47:19.000+02:00
#     Task TSK30: Product=PFD29 Device=DVC3 Details=4
#       Start: 2024-08-11T19:54:05.000+02:00 End: 2024-08-12T14:47:19.000+02:00
#     Task TSK31: Product=PFD29 Device=DVC6 Details=4
#       Start: 2024-08-11T19:54:05.000+02:00 End: 2024-08-12T14:47:19.000+02:00
#   Field: 013-0, Hulegaard b.
#     Task TSK179: Product=PFD39 Device=DVC2 Details=4
#       Start: 2024-08-11T18:39:06.000+02:00 End: 2024-08-12T14:49:39.000+02:00
#     Task TSK180: Product=PFD39 Device=DVC3 Details=4
#       Start: 2024-08-11T18:39:06.000+02:00 End: 2024-08-12T14:49:39.000+02:00
#     Task TSK181: Product=PFD39 Device=DVC6 Details=4
#       Start: 2024-08-11T18:39:06.000+02:00 End: 2024-08-12T14:49:39.000+02:00
#   Field: 014-0, Dellingemølle
#     Task TSK184: Product=PFD59 Device=DVC2 Details=4
#       Start: 2024-08-28T15:17:14.000+02:00 End: 2024-08-28T21:32:20.000+02:00
#     Task TSK185: Product=PFD59 Device=DVC6 Details=4
#       Start: 2024-08-28T15:17:14.000+02:00 End: 2024-08-28T21:32:20.000+02:00
#   Field: 015-0, Hulemølle
#     Task TSK75: Product=PFD2 Device=DVC5 Details=4
#       Start: 2024-07-20T20:52:48.000+02:00 End: 2024-07-29T13:37:20.000+02:00
#     Task TSK76: Product=PFD2 Device=DVC3 Details=4
#       Start: 2024-07-20T20:52:48.000+02:00 End: 2024-07-29T13:37:20.000+02:00
#     Task TSK77: Product=PFD2 Device=DVC6 Details=4
#       Start: 2024-07-20T20:52:48.000+02:00 End: 2024-07-29T13:37:20.000+02:00
#   Field: 016-0, Stendyssegård
#     Task TSK211: Product=PFD47 Device=DVC4 Details=4
#       Start: 2024-07-30T18:35:12.000+02:00 End: 2024-07-31T15:17:25.000+02:00
#     Task TSK212: Product=PFD47 Device=DVC3 Details=4
#       Start: 2024-07-30T18:35:12.000+02:00 End: 2024-07-31T15:17:25.000+02:00
#     Task TSK213: Product=PFD47 Device=DVC5 Details=4
#       Start: 2024-07-30T18:35:12.000+02:00 End: 2024-07-31T15:17:25.000+02:00
#     Task TSK214: Product=PFD47 Device=DVC6 Details=4
#       Start: 2024-07-30T18:35:12.000+02:00 End: 2024-07-31T15:17:25.000+02:00
#   Field: 016-1, Stendyssegård Venstr
#     Task TSK89: Product=PFD69 Device=DVC3 Details=4
#       Start: 2024-07-30T17:22:22.000+02:00 End: 2024-07-30T18:53:06.000+02:00
#     Task TSK90: Product=PFD69 Device=DVC4 Details=4
#       Start: 2024-07-30T17:22:22.000+02:00 End: 2024-07-30T18:53:06.000+02:00
#     Task TSK91: Product=PFD69 Device=DVC5 Details=4
#       Start: 2024-07-30T17:22:22.000+02:00 End: 2024-07-30T18:53:06.000+02:00
#     Task TSK92: Product=PFD69 Device=DVC6 Details=4
#       Start: 2024-07-30T17:22:22.000+02:00 End: 2024-07-30T18:53:06.000+02:00
#   Field: 016-2, Stendyssegård Højre
#     Task TSK199: Product=PFD14 Device=DVC4 Details=4
#       Start: 2024-07-29T13:39:08.000+02:00 End: 2024-07-30T17:57:27.000+02:00
#     Task TSK200: Product=PFD14 Device=DVC3 Details=4
#       Start: 2024-07-29T13:39:08.000+02:00 End: 2024-07-30T17:57:27.000+02:00
#     Task TSK201: Product=PFD14 Device=DVC5 Details=4
#       Start: 2024-07-29T13:39:08.000+02:00 End: 2024-07-30T17:57:27.000+02:00
#     Task TSK202: Product=PFD14 Device=DVC6 Details=4
#       Start: 2024-07-29T13:39:08.000+02:00 End: 2024-07-30T17:57:27.000+02:00
#   Field: 016-3, Stendysegård fold
#     Task TSK102: Product=PFD18 Device=DVC3 Details=4
#       Start: 2024-08-13T12:42:52.000+02:00 End: 2024-08-13T16:16:49.000+02:00
#     Task TSK103: Product=PFD18 Device=DVC6 Details=4
#       Start: 2024-08-13T12:42:52.000+02:00 End: 2024-08-13T16:16:49.000+02:00
#   Field: 021-0, Monica
#     Task TSK1: Product=PFD43 Device=DVC2 Details=4
#       Start: 2024-07-30T20:44:39.000+02:00 End: 2024-07-31T12:48:54.000+02:00
#     Task TSK2: Product=PFD43 Device=DVC1 Details=4
#       Start: 2024-07-30T20:44:39.000+02:00 End: 2024-07-31T12:48:54.000+02:00
#     Task TSK3: Product=PFD43 Device=DVC6 Details=4
#       Start: 2024-07-30T20:44:39.000+02:00 End: 2024-07-31T12:48:54.000+02:00
#   Field: 022-0, Lidia
#     Task TSK52: Product=PFD24 Device=DVC1 Details=4
#       Start: 2024-07-30T15:11:53.000+02:00 End: 2024-07-31T13:13:05.000+02:00
#     Task TSK53: Product=PFD24 Device=DVC2 Details=4
#       Start: 2024-07-30T15:11:53.000+02:00 End: 2024-07-31T13:13:05.000+02:00
#     Task TSK54: Product=PFD24 Device=DVC6 Details=4
#       Start: 2024-07-30T15:11:53.000+02:00 End: 2024-07-31T13:13:05.000+02:00
#   Field: 023-0, Veronica 1
#     Task TSK60: Product=PFD40 Device=DVC3 Details=4
#       Start: 2024-08-13T17:09:59.000+02:00 End: 2024-08-13T18:34:24.000+02:00
#     Task TSK61: Product=PFD40 Device=DVC2 Details=4
#       Start: 2024-08-13T17:09:59.000+02:00 End: 2024-08-13T18:34:24.000+02:00
#     Task TSK62: Product=PFD40 Device=DVC6 Details=4
#       Start: 2024-08-13T17:09:59.000+02:00 End: 2024-08-13T18:34:24.000+02:00
#   Field: 023-2, Veronica 2
#     Task TSK69: Product=PFD50 Device=DVC2 Details=4
#       Start: 2024-08-13T17:16:44.000+02:00 End: 2024-08-13T17:52:39.000+02:00
#     Task TSK70: Product=PFD50 Device=DVC3 Details=4
#       Start: 2024-08-13T17:16:44.000+02:00 End: 2024-08-13T17:52:39.000+02:00
#     Task TSK71: Product=PFD50 Device=DVC6 Details=4
#       Start: 2024-08-13T17:16:44.000+02:00 End: 2024-08-13T17:52:39.000+02:00
#   Field: 024-0, Silvia
#     Task TSK141: Product=PFD67 Device=DVC3 Details=4
#       Start: 2024-08-14T11:52:27.000+02:00 End: 2024-08-14T16:44:59.000+02:00
#     Task TSK142: Product=PFD67 Device=DVC6 Details=4
#       Start: 2024-08-14T11:52:27.000+02:00 End: 2024-08-14T16:44:59.000+02:00
#   Field: 025-0, Camilla/Tatiana
#     Task TSK203: Product=PFD65 Device=DVC2 Details=4
#       Start: 2024-08-13T16:56:54.000+02:00 End: 2024-08-14T11:52:12.000+02:00
#     Task TSK204: Product=PFD65 Device=DVC3 Details=4
#       Start: 2024-08-13T16:56:54.000+02:00 End: 2024-08-14T11:52:12.000+02:00
#     Task TSK205: Product=PFD65 Device=DVC6 Details=4
#       Start: 2024-08-13T16:56:54.000+02:00 End: 2024-08-14T11:52:12.000+02:00
#   Field: 035-0, Bispegård mark
#     Task TSK112: Product=PFD4 Device=DVC4 Details=4
#       Start: 2024-07-21T19:53:43.000+02:00 End: 2024-07-30T11:38:26.000+02:00
#     Task TSK113: Product=PFD4 Device=DVC3 Details=4
#       Start: 2024-07-21T19:53:43.000+02:00 End: 2024-07-30T11:38:26.000+02:00
#     Task TSK114: Product=PFD4 Device=DVC5 Details=4
#       Start: 2024-07-21T19:53:43.000+02:00 End: 2024-07-30T11:38:26.000+02:00
#     Task TSK115: Product=PFD4 Device=DVC6 Details=4
#       Start: 2024-07-21T19:53:43.000+02:00 End: 2024-07-30T11:38:26.000+02:00
#   Field: 036-0, Bispegård vest
#     Task TSK121: Product=PFD42 Device=DVC5 Details=4
#       Start: 2024-07-20T10:27:08.000+02:00 End: 2024-07-30T16:52:27.000+02:00
#     Task TSK122: Product=PFD42 Device=DVC4 Details=4
#       Start: 2024-07-20T10:27:08.000+02:00 End: 2024-07-30T16:52:27.000+02:00
#     Task TSK123: Product=PFD42 Device=DVC3 Details=4
#       Start: 2024-07-20T10:27:08.000+02:00 End: 2024-07-30T16:52:27.000+02:00
#     Task TSK124: Product=PFD42 Device=DVC6 Details=4
#       Start: 2024-07-20T10:27:08.000+02:00 End: 2024-07-30T16:52:27.000+02:00
#   Field: 037-0, Bispegård øst
#     Task TSK175: Product=PFD73 Device=DVC4 Details=4
#       Start: 2024-07-20T10:04:24.000+02:00 End: 2024-07-30T16:51:05.000+02:00
#     Task TSK176: Product=PFD73 Device=DVC3 Details=4
#       Start: 2024-07-20T10:04:24.000+02:00 End: 2024-07-30T16:51:05.000+02:00
#     Task TSK177: Product=PFD73 Device=DVC5 Details=4
#       Start: 2024-07-20T10:04:24.000+02:00 End: 2024-07-30T16:51:05.000+02:00
#     Task TSK178: Product=PFD73 Device=DVC6 Details=4
#       Start: 2024-07-20T10:04:24.000+02:00 End: 2024-07-30T16:51:05.000+02:00
#   Field: 039-0, Holmegård nord
#     Task TSK49: Product=PFD15 Device=DVC2 Details=4
#       Start: 2024-08-13T13:26:49.000+02:00 End: 2024-08-13T14:40:08.000+02:00
#     Task TSK50: Product=PFD15 Device=DVC3 Details=4
#       Start: 2024-08-13T13:26:49.000+02:00 End: 2024-08-13T14:40:08.000+02:00
#     Task TSK51: Product=PFD15 Device=DVC6 Details=4
#       Start: 2024-08-13T13:26:49.000+02:00 End: 2024-08-13T14:40:08.000+02:00
#   Field: 040-0, Holmegård syd
#     Task TSK24: Product=PFD21 Device=DVC3 Details=4
#       Start: 2024-08-13T14:36:07.000+02:00 End: 2024-08-13T16:12:04.000+02:00
#     Task TSK25: Product=PFD21 Device=DVC2 Details=4
#       Start: 2024-08-13T14:36:07.000+02:00 End: 2024-08-13T16:12:04.000+02:00
#     Task TSK26: Product=PFD21 Device=DVC6 Details=4
#       Start: 2024-08-13T14:36:07.000+02:00 End: 2024-08-13T16:12:04.000+02:00
#
# Year: 2025
#   Field: Import
#     Task TSK66: Product=PFD6 Device=DVC2 Details=4
#       Start: 2025-07-18T12:21:30.000+02:00 End: 2025-07-19T11:36:51.000+02:00
#     Task TSK67: Product=PFD6 Device=DVC1 Details=4
#       Start: 2025-07-18T12:21:30.000+02:00 End: 2025-07-19T11:36:51.000+02:00
#     Task TSK68: Product=PFD6 Device=DVC6 Details=4
#       Start: 2025-07-18T12:21:30.000+02:00 End: 2025-07-19T11:36:51.000+02:00
#     Task TSK118: Product=PFD44 Device=DVC2 Details=4
#       Start: 2025-07-19T12:58:51.000+02:00 End: 2025-07-19T21:21:31.000+02:00
#     Task TSK119: Product=PFD44 Device=DVC1 Details=4
#       Start: 2025-07-19T12:58:51.000+02:00 End: 2025-07-19T21:21:31.000+02:00
#     Task TSK120: Product=PFD44 Device=DVC6 Details=4
#       Start: 2025-07-19T12:58:51.000+02:00 End: 2025-07-19T21:21:31.000+02:00
#     Task TSK72: Product=PFD75 Device=DVC1 Details=4
#       Start: 2025-08-05T17:22:33.000+02:00 End: 2025-08-08T16:08:50.000+02:00
#     Task TSK73: Product=PFD75 Device=DVC2 Details=4
#       Start: 2025-08-05T17:22:33.000+02:00 End: 2025-08-08T16:08:50.000+02:00
#     Task TSK74: Product=PFD75 Device=DVC6 Details=4
#       Start: 2025-08-05T17:22:33.000+02:00 End: 2025-08-08T16:08:50.000+02:00
#     Task TSK170: Product=PFD35 Device=DVC1 Details=4
#       Start: 2025-08-05T18:01:31.000+02:00 End: 2025-08-08T16:07:45.000+02:00
#     Task TSK171: Product=PFD35 Device=DVC2 Details=4
#       Start: 2025-08-05T18:01:31.000+02:00 End: 2025-08-08T16:07:45.000+02:00
#     Task TSK172: Product=PFD35 Device=DVC6 Details=4
#       Start: 2025-08-05T18:01:31.000+02:00 End: 2025-08-08T16:07:45.000+02:00
#     Task TSK152: Product=PFD37 Device=DVC2 Details=4
#       Start: 2025-08-05T19:37:48.000+02:00 End: 2025-08-08T16:22:56.000+02:00
#     Task TSK153: Product=PFD37 Device=DVC1 Details=4
#       Start: 2025-08-05T19:37:48.000+02:00 End: 2025-08-08T16:22:56.000+02:00
#     Task TSK154: Product=PFD37 Device=DVC6 Details=4
#       Start: 2025-08-05T19:37:48.000+02:00 End: 2025-08-08T16:22:56.000+02:00
#     Task TSK193: Product=PFD64 Device=DVC1 Details=4
#       Start: 2025-08-05T19:56:17.000+02:00 End: 2025-08-08T11:45:10.000+02:00
#     Task TSK194: Product=PFD64 Device=DVC2 Details=4
#       Start: 2025-08-05T19:56:17.000+02:00 End: 2025-08-08T11:45:10.000+02:00
#     Task TSK195: Product=PFD64 Device=DVC6 Details=4
#       Start: 2025-08-05T19:56:17.000+02:00 End: 2025-08-08T11:45:10.000+02:00
#     Task TSK138: Product=PFD68 Device=DVC1 Details=4
#       Start: 2025-08-05T20:58:16.000+02:00 End: 2025-08-06T07:44:27.000+02:00
#     Task TSK139: Product=PFD68 Device=DVC2 Details=4
#       Start: 2025-08-05T20:58:16.000+02:00 End: 2025-08-06T07:44:27.000+02:00
#     Task TSK140: Product=PFD68 Device=DVC6 Details=4
#       Start: 2025-08-05T20:58:16.000+02:00 End: 2025-08-06T07:44:27.000+02:00
#     Task TSK196: Product=PFD38 Device=DVC2 Details=4
#       Start: 2025-08-08T09:40:40.000+02:00 End: 2025-08-08T11:42:35.000+02:00
#     Task TSK197: Product=PFD38 Device=DVC1 Details=4
#       Start: 2025-08-08T09:40:40.000+02:00 End: 2025-08-08T11:42:35.000+02:00
#     Task TSK198: Product=PFD38 Device=DVC6 Details=4
#       Start: 2025-08-08T09:40:40.000+02:00 End: 2025-08-08T11:42:35.000+02:00
#     Task TSK155: Product=PFD62 Device=DVC2 Details=4
#       Start: 2025-08-08T09:53:20.000+02:00 End: 2025-08-08T11:41:25.000+02:00
#     Task TSK156: Product=PFD62 Device=DVC1 Details=4
#       Start: 2025-08-08T09:53:20.000+02:00 End: 2025-08-08T11:41:25.000+02:00
#     Task TSK157: Product=PFD62 Device=DVC6 Details=4
#       Start: 2025-08-08T09:53:20.000+02:00 End: 2025-08-08T11:41:25.000+02:00
#     Task TSK143: Product=PFD7 Device=DVC2 Details=4
#       Start: 2025-08-08T11:44:35.000+02:00 End: 2025-08-08T16:12:30.000+02:00
#     Task TSK144: Product=PFD7 Device=DVC1 Details=4
#       Start: 2025-08-08T11:44:35.000+02:00 End: 2025-08-08T16:12:30.000+02:00
#     Task TSK145: Product=PFD7 Device=DVC6 Details=4
#       Start: 2025-08-08T11:44:35.000+02:00 End: 2025-08-08T16:12:30.000+02:00
#     Task TSK35: Product=PFD72 Device=DVC1 Details=4
#       Start: 2025-08-08T16:09:20.000+02:00 End: 2025-08-08T18:17:05.000+02:00
#     Task TSK36: Product=PFD72 Device=DVC2 Details=4
#       Start: 2025-08-08T16:09:20.000+02:00 End: 2025-08-08T18:17:05.000+02:00
#     Task TSK37: Product=PFD72 Device=DVC6 Details=4
#       Start: 2025-08-08T16:09:20.000+02:00 End: 2025-08-08T18:17:05.000+02:00
#     Task TSK99: Product=PFD26 Device=DVC1 Details=4
#       Start: 2025-08-08T17:35:45.000+02:00 End: 2025-08-08T18:01:05.000+02:00
#     Task TSK100: Product=PFD26 Device=DVC2 Details=4
#       Start: 2025-08-08T17:35:45.000+02:00 End: 2025-08-08T18:01:05.000+02:00
#     Task TSK101: Product=PFD26 Device=DVC6 Details=4
#       Start: 2025-08-08T17:35:45.000+02:00 End: 2025-08-08T18:01:05.000+02:00
#     Task TSK4: Product=PFD74 Device=DVC1 Details=4
#       Start: 2025-08-08T18:34:34.000+02:00 End: 2025-08-10T14:19:08.000+02:00
#     Task TSK5: Product=PFD74 Device=DVC2 Details=4
#       Start: 2025-08-08T18:34:34.000+02:00 End: 2025-08-10T14:19:08.000+02:00
#     Task TSK6: Product=PFD74 Device=DVC6 Details=4
#       Start: 2025-08-08T18:34:34.000+02:00 End: 2025-08-10T14:19:08.000+02:00
#     Task TSK78: Product=PFD1 Device=DVC1 Details=4
#       Start: 2025-08-08T18:42:35.000+02:00 End: 2025-08-10T14:38:48.000+02:00
#     Task TSK79: Product=PFD1 Device=DVC2 Details=4
#       Start: 2025-08-08T18:42:35.000+02:00 End: 2025-08-10T14:38:48.000+02:00
#     Task TSK80: Product=PFD1 Device=DVC6 Details=4
#       Start: 2025-08-08T18:42:35.000+02:00 End: 2025-08-10T14:38:48.000+02:00
#     Task TSK7: Product=PFD51 Device=DVC1 Details=4
#       Start: 2025-08-09T09:47:30.000+02:00 End: 2025-08-09T15:19:50.000+02:00
#     Task TSK8: Product=PFD51 Device=DVC2 Details=4
#       Start: 2025-08-09T09:47:30.000+02:00 End: 2025-08-09T15:19:50.000+02:00
#     Task TSK9: Product=PFD51 Device=DVC6 Details=4
#       Start: 2025-08-09T09:47:30.000+02:00 End: 2025-08-09T15:19:50.000+02:00
#     Task TSK206: Product=PFD8 Device=DVC2 Details=4
#       Start: 2025-08-09T10:41:45.000+02:00 End: 2025-08-09T15:18:00.000+02:00
#     Task TSK207: Product=PFD8 Device=DVC1 Details=4
#       Start: 2025-08-09T10:41:45.000+02:00 End: 2025-08-09T15:18:00.000+02:00
#     Task TSK208: Product=PFD8 Device=DVC6 Details=4
#       Start: 2025-08-09T10:41:45.000+02:00 End: 2025-08-09T15:18:00.000+02:00
#     Task TSK41: Product=PFD53 Device=DVC1 Details=4
#       Start: 2025-08-09T13:58:25.000+02:00 End: 2025-08-09T15:15:45.000+02:00
#     Task TSK42: Product=PFD53 Device=DVC2 Details=4
#       Start: 2025-08-09T13:58:25.000+02:00 End: 2025-08-09T15:15:45.000+02:00
#     Task TSK43: Product=PFD53 Device=DVC6 Details=4
#       Start: 2025-08-09T13:58:25.000+02:00 End: 2025-08-09T15:15:45.000+02:00
#     Task TSK158: Product=PFD60 Device=DVC2 Details=4
#       Start: 2025-08-09T15:48:40.000+02:00 End: 2025-08-09T21:51:32.000+02:00
#     Task TSK159: Product=PFD60 Device=DVC1 Details=4
#       Start: 2025-08-09T15:48:40.000+02:00 End: 2025-08-09T21:51:32.000+02:00
#     Task TSK160: Product=PFD60 Device=DVC6 Details=4
#       Start: 2025-08-09T15:48:40.000+02:00 End: 2025-08-09T21:51:32.000+02:00
#     Task TSK161: Product=PFD58 Device=DVC2 Details=4
#       Start: 2025-08-09T16:00:25.000+02:00 End: 2025-08-09T17:33:05.000+02:00
#     Task TSK162: Product=PFD58 Device=DVC1 Details=4
#       Start: 2025-08-09T16:00:25.000+02:00 End: 2025-08-09T17:33:05.000+02:00
#     Task TSK163: Product=PFD58 Device=DVC6 Details=4
#       Start: 2025-08-09T16:00:25.000+02:00 End: 2025-08-09T17:33:05.000+02:00
#     Task TSK81: Product=PFD13 Device=DVC2 Details=4
#       Start: 2025-08-09T16:56:45.000+02:00 End: 2025-08-09T17:31:00.000+02:00
#     Task TSK82: Product=PFD13 Device=DVC1 Details=4
#       Start: 2025-08-09T16:56:45.000+02:00 End: 2025-08-09T17:31:00.000+02:00
#     Task TSK83: Product=PFD13 Device=DVC6 Details=4
#       Start: 2025-08-09T16:56:45.000+02:00 End: 2025-08-09T17:31:00.000+02:00
#     Task TSK125: Product=PFD28 Device=DVC1 Details=4
#       Start: 2025-08-10T13:00:07.000+02:00 End: 2025-08-10T14:14:48.000+02:00
#     Task TSK126: Product=PFD28 Device=DVC2 Details=4
#       Start: 2025-08-10T13:00:07.000+02:00 End: 2025-08-10T14:14:48.000+02:00
#     Task TSK127: Product=PFD28 Device=DVC6 Details=4
#       Start: 2025-08-10T13:00:07.000+02:00 End: 2025-08-10T14:14:48.000+02:00

# %%
import importlib
import pyagri.taskdata_report
importlib.reload(pyagri.taskdata_report)
from pyagri.taskdata_report import taskdata_report_df

# %%
# --- Display TASKDATA.XML report as a DataFrame ---
from pyagri.taskdata_report import taskdata_report_df
from IPython.display import display

xml_path = PROJECT_ROOT / 'data' / 'taskdata' / 'TASKDATA.XML'
df_report = taskdata_report_df(xml_path)
display(df_report)
# Out:
#      Year                          Field  TaskID Product   Crop Details  \
# 188  2022  002-0, St.Amalienborg/Litgoth  TSK189   PFD54  DET10       4
# 189  2022  002-0, St.Amalienborg/Litgoth  TSK190   PFD54  DET40       4
# 190  2022  002-0, St.Amalienborg/Litgoth  TSK191   PFD54  DET30       4
# 191  2022  002-0, St.Amalienborg/Litgoth  TSK192   PFD54  DET64       4
# 181  2022               010-0, Møllemark  TSK182   PFD52  DET10       4
# ..    ...                            ...     ...     ...    ...     ...
# 81   2025                         Import   TSK82   PFD13  DET10       4
# 82   2025                         Import   TSK83   PFD13  DET64       4
# 124  2025                         Import  TSK125   PFD28  DET10       4
# 125  2025                         Import  TSK126   PFD28  DET20       4
# 126  2025                         Import  TSK127   PFD28  DET64       4
#
#                          StartTime                        EndTime Device  \
# 188  2022-08-04T18:06:44.000+02:00  2022-08-13T22:30:35.000+02:00   DVC1
# 189  2022-08-04T18:06:44.000+02:00  2022-08-13T22:30:35.000+02:00   DVC4
# 190  2022-08-04T18:06:44.000+02:00  2022-08-13T22:30:35.000+02:00   DVC3
# 191  2022-08-04T18:06:44.000+02:00  2022-08-13T22:30:35.000+02:00   DVC6
# 181  2022-08-13T14:32:41.000+02:00  2022-08-13T18:46:03.000+02:00   DVC1
# ..                             ...                            ...    ...
# 81   2025-08-09T16:56:45.000+02:00  2025-08-09T17:31:00.000+02:00   DVC1
# 82   2025-08-09T16:56:45.000+02:00  2025-08-09T17:31:00.000+02:00   DVC6
# 124  2025-08-10T13:00:07.000+02:00  2025-08-10T14:14:48.000+02:00   DVC1
# 125  2025-08-10T13:00:07.000+02:00  2025-08-10T14:14:48.000+02:00   DVC2
# 126  2025-08-10T13:00:07.000+02:00  2025-08-10T14:14:48.000+02:00   DVC6
#
#           TLG                       Sensors
# 188  TLG00123  005A, 0074, 0077, 0106, 013B
# 189  TLG00124  005A, 0074, 0077, 0106, 013B
# 190  TLG00125  005A, 0074, 0077, 0106, 013B
# 191      None        005A, 0077, 0106, 013B
# 181  TLG00119  005A, 0074, 0077, 0106, 013B
# ..        ...                           ...
# 81   TLG00054  005A, 0074, 0077, 0106, 013B
# 82       None        005A, 0077, 0106, 013B
# 124  TLG00082  005A, 0074, 0077, 0106, 013B
# 125  TLG00083  005A, 0074, 0077, 0106, 013B
# 126      None        005A, 0077, 0106, 013B
#
# [217 rows x 11 columns]

# %% [markdown]
# ## Premlmary data analasis
# The data is now loaded and the following cells contain simpel valdation of the input

# %%
# --- GeoJSON Year Investigation ---
import geopandas as gpd
import pandas as pd
from IPython.display import display

# Load the GeoJSON file
gdf = gpd.read_file(FIELD_POLYGONS_GEOJSON)

# List all unique years in the 'Year' attribute
years = sorted(gdf['Year'].dropna().unique())
print(f"Unique years in GeoJSON: {years}")
display(pd.DataFrame({'Year': years}))
# Out:
# Unique years in GeoJSON: [np.int32(2021), np.int32(2022), np.int32(2023), np.int32(2024), np.int32(2025)]
#    Year
# 0  2021
# 1  2022
# 2  2023
# 3  2024
# 4  2025

# %%
# Reproject GeoDataFrame to the target CRS for analysis
gdf_proj = gdf.to_crs(epsg=EPSG)
print(f"Reprojected GeoDataFrame to EPSG:{EPSG} for area/overlap analysis.")
# Out:
# Reprojected GeoDataFrame to EPSG:25832 for area/overlap analysis.

# %%
# --- Check for overlapping polygons within each year (projected CRS) ---
from shapely.geometry import Polygon
from shapely.ops import unary_union

# Function to find overlapping polygons in a GeoDataFrame for a given year
def find_overlaps(gdf_year):
    overlaps = []
    for i, row1 in gdf_year.iterrows():
        for j, row2 in gdf_year.iterrows():
            if i >= j:
                continue
            if row1['geometry'].intersects(row2['geometry']):
                intersection = row1['geometry'].intersection(row2['geometry'])
                if not intersection.is_empty and intersection.area > 0:
                    overlaps.append((i, j, intersection.area))
    return overlaps

# Analyze overlaps for each year using the projected GeoDataFrame
overlap_summary = {}
for year in years:
    gdf_year = gdf_proj[gdf_proj['Year'] == year]
    overlaps = find_overlaps(gdf_year)
    overlap_summary[year] = overlaps
    print(f"Year {year}: {len(overlaps)} overlapping pairs found.")
    if overlaps:
        for i, j, area in overlaps:
            print(f"  Overlap between index {i} and {j}, area: {area:.2f} m²")

# Optionally, display summary as a DataFrame
overlap_counts = pd.DataFrame({
    'Year': list(overlap_summary.keys()),
    'Num Overlaps': [len(v) for v in overlap_summary.values()]
})
display(overlap_counts)
# Out:
# Year 2021: 14 overlapping pairs found.
#   Overlap between index 2 and 3, area: 114092.87 m²
#   Overlap between index 8 and 9, area: 60366.70 m²
#   Overlap between index 10 and 11, area: 43302.90 m²
#   Overlap between index 10 and 29, area: 43302.90 m²
#   Overlap between index 11 and 29, area: 43302.90 m²
#   Overlap between index 12 and 13, area: 175356.26 m²
#   Overlap between index 16 and 17, area: 109298.54 m²
#   Overlap between index 18 and 19, area: 210481.65 m²
#   Overlap between index 26 and 27, area: 269055.94 m²
#   Overlap between index 28 and 41, area: 83364.05 m²
#   Overlap between index 28 and 42, area: 83364.05 m²
#   Overlap between index 32 and 33, area: 24295.68 m²
#   Overlap between index 38 and 39, area: 102238.25 m²
#   Overlap between index 41 and 42, area: 83364.05 m²
# Year 2022: 12 overlapping pairs found.
#   Overlap between index 0 and 1, area: 72749.90 m²
#   Overlap between index 4 and 5, area: 24295.68 m²
#   Overlap between index 22 and 23, area: 114092.87 m²
#   Overlap between index 24 and 25, area: 83364.05 m²
#   Overlap between index 34 and 35, area: 403414.24 m²
#   Overlap between index 36 and 37, area: 245113.92 m²
#   Overlap between index 45 and 46, area: 102238.25 m²
#   Overlap between index 71 and 72, area: 175356.26 m²
#   Overlap between index 109 and 110, area: 210481.65 m²
#   Overlap between index 169 and 170, area: 295743.78 m²
#   Overlap between index 169 and 171, area: 295743.78 m²
#   Overlap between index 170 and 171, area: 295743.78 m²
# Year 2023: 18 overlapping pairs found.
#   Overlap between index 53 and 54, area: 642984.91 m²
#   Overlap between index 53 and 55, area: 642984.91 m²
#   Overlap between index 54 and 55, area: 642984.91 m²
#   Overlap between index 57 and 58, area: 105125.25 m²
#   Overlap between index 60 and 61, area: 42355.69 m²
#   Overlap between index 67 and 68, area: 210481.65 m²
#   Overlap between index 76 and 77, area: 83286.83 m²
#   Overlap between index 82 and 83, area: 17743.46 m²
#   Overlap between index 101 and 102, area: 175355.72 m²
#   Overlap between index 107 and 108, area: 243178.39 m²
#   Overlap between index 114 and 115, area: 402724.86 m²
#   Overlap between index 117 and 118, area: 102238.25 m²
#   Overlap between index 134 and 135, area: 269056.05 m²
#   Overlap between index 141 and 142, area: 114092.87 m²
#   Overlap between index 143 and 144, area: 28492.65 m²
#   Overlap between index 153 and 154, area: 60366.70 m²
#   Overlap between index 155 and 156, area: 293856.16 m²
#   Overlap between index 187 and 188, area: 206783.28 m²
# Year 2024: 31 overlapping pairs found.
#   Overlap between index 47 and 48, area: 72749.87 m²
#   Overlap between index 62 and 63, area: 81007.78 m²
#   Overlap between index 65 and 66, area: 263180.51 m²
#   Overlap between index 78 and 79, area: 56048.88 m²
#   Overlap between index 80 and 81, area: 635172.79 m²
#   Overlap between index 85 and 86, area: 83286.85 m²
#   Overlap between index 87 and 88, area: 190339.94 m²
#   Overlap between index 91 and 92, area: 42355.69 m²
#   Overlap between index 95 and 96, area: 209226.49 m²
#   Overlap between index 104 and 105, area: 28492.16 m²
#   Overlap between index 104 and 106, area: 28492.16 m²
#   Overlap between index 105 and 106, area: 28492.16 m²
#   Overlap between index 119 and 120, area: 175355.56 m²
#   Overlap between index 119 and 121, area: 175355.56 m²
#   Overlap between index 120 and 121, area: 175355.56 m²
#   Overlap between index 125 and 126, area: 102237.98 m²
#   Overlap between index 125 and 127, area: 102237.98 m²
#   Overlap between index 126 and 127, area: 102237.98 m²
#   Overlap between index 132 and 133, area: 293856.16 m²
#   Overlap between index 160 and 161, area: 24295.55 m²
#   Overlap between index 160 and 162, area: 24295.55 m²
#   Overlap between index 161 and 162, area: 24295.55 m²
#   Overlap between index 163 and 164, area: 58031.62 m²
#   Overlap between index 167 and 168, area: 105125.25 m²
#   Overlap between index 176 and 177, area: 17743.36 m²
#   Overlap between index 176 and 178, area: 17743.36 m²
#   Overlap between index 177 and 178, area: 17743.36 m²
#   Overlap between index 179 and 180, area: 402725.22 m²
#   Overlap between index 184 and 185, area: 114094.11 m²
#   Overlap between index 184 and 186, area: 114094.11 m²
#   Overlap between index 185 and 186, area: 114094.11 m²
# Year 2025: 25 overlapping pairs found.
#   Overlap between index 49 and 50, area: 641830.78 m²
#   Overlap between index 51 and 52, area: 60379.08 m²
#   Overlap between index 69 and 70, area: 104459.46 m²
#   Overlap between index 73 and 74, area: 106290.23 m²
#   Overlap between index 89 and 90, area: 294475.05 m²
#   Overlap between index 93 and 94, area: 139049.05 m²
#   Overlap between index 97 and 98, area: 243180.48 m²
#   Overlap between index 99 and 100, area: 42355.10 m²
#   Overlap between index 111 and 112, area: 29122.71 m²
#   Overlap between index 123 and 124, area: 225662.79 m²
#   Overlap between index 128 and 129, area: 72750.13 m²
#   Overlap between index 136 and 137, area: 83118.44 m²
#   Overlap between index 139 and 140, area: 208317.79 m²
#   Overlap between index 145 and 146, area: 58783.98 m²
#   Overlap between index 147 and 148, area: 114093.38 m²
#   Overlap between index 149 and 150, area: 403291.65 m²
#   Overlap between index 149 and 151, area: 0.00 m²
#   Overlap between index 149 and 152, area: 0.00 m²
#   Overlap between index 150 and 151, area: 0.00 m²
#   Overlap between index 150 and 152, area: 0.00 m²
#   Overlap between index 151 and 152, area: 83286.64 m²
#   Overlap between index 157 and 158, area: 183602.01 m²
#   Overlap between index 172 and 173, area: 17743.73 m²
#   Overlap between index 174 and 175, area: 25329.26 m²
#   Overlap between index 181 and 182, area: 280184.54 m²
#    Year  Num Overlaps
# 0  2021            14
# 1  2022            12
# 2  2023            18
# 3  2024            31
# 4  2025            25

# %%
# --- Display features for a selected year ---
import ipywidgets as widgets
from IPython.display import display

# Dropdown widget for year selection
year_selector = widgets.Dropdown(
    options=years,
    description='Year:',
    value=years[0] if years else None
)

def show_features_for_year(selected_year):
    gdf_year = gdf[gdf['Year'] == selected_year]
    print(f"Features for year {selected_year} (count: {len(gdf_year)}):")
    display(gdf_year)
    try:
        gdf_year.explore()
    except Exception:
        print("Map display requires geopandas 0.10+ and folium.")

widgets.interact(show_features_for_year, selected_year=year_selector)
# Out:
# interactive(children=(Dropdown(description='Year:', options=(np.int32(2021), np.int32(2022), np.int32(2023), n…
# <function __main__.show_features_for_year(selected_year)>

# %%
import xml.etree.ElementTree as ET
from collections import defaultdict

def parse_isoxml_taskdata(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # 1. Extract Farm Name (FRM)
    # ISOXML structure: root -> FRM
    farms = {}
    for frm in root.findall('FRM'):
        # A=ID, B=Name
        farms[frm.attrib.get('A')] = frm.attrib.get('B', 'Unknown Farm')
    
    # 2. Extract Fields (PFD)
    # Map PFD ID -> Field Name
    fields = {}
    for pfd in root.findall('PFD'):
        pfd_id = pfd.attrib.get('A')
        # B is typically Code/Name, C is Description. 
        # User asked for "024-0" which is usually in B or C.
        name = pfd.attrib.get('C') or pfd.attrib.get('B') or "Unknown Field"
        fields[pfd_id] = name

    # 3. Extract Device Descriptions (DVC) for Danish Names (DPD)
    # Map DDI (hex) -> Danish Name (E attribute in DPD)
    # Also map Device ID -> Device Name
    devices = {}
    ddi_definitions = {} # Key: DDI (e.g., '0074'), Value: Name (e.g., 'Bearb. areal')
    
    for dvc in root.findall('DVC'):
        dvc_id = dvc.attrib.get('A')
        dvc_name = dvc.attrib.get('B', 'Unknown Machine')
        devices[dvc_id] = dvc_name
        
        # Look for DeviceProcessData (DPD) definitions inside the Device
        # DET -> DPD or direct DPD depending on version
        # Usually DVC -> DPD in flattened exports or DVC -> DET -> DPD
        for dpd in dvc.findall('.//DPD'):
            ddi = dpd.attrib.get('B') # The DDI Number (e.g., 0074)
            name = dpd.attrib.get('E') # The Designator (Danish Name)
            if ddi and name:
                ddi_definitions[ddi] = name

    # 4. Process Tasks (TSK)
    # Structure: Farm -> Year -> Field -> Task
    report_data = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

    ns = {'iso': ''} # Namespace handling if needed, usually clear in standard parsing

    for tsk in root.findall('TSK'):
        tsk_id = tsk.attrib.get('A')
        field_ref = tsk.attrib.get('E') # Reference to PFD
        
        # Determine Year from Time (TIM) start
        # Try to find a TIM tag
        tim = tsk.find('TIM')
        year = "Unknown Year"
        if tim is not None and 'A' in tim.attrib:
            # Format usually YYYY-MM-DDThh:mm:ss
            year = tim.attrib['A'][:4]
        
        # Resolve Field Name
        field_name = fields.get(field_ref, f"Field ID {field_ref}")

        # Resolve Machine
        # DAN (DeviceAllocation) -> C attribute is DVC ID
        dan = tsk.find('DAN')
        machine_name = "Unknown Machine"
        if dan is not None:
            dvc_ref = dan.attrib.get('C')
            machine_name = devices.get(dvc_ref, dvc_ref)

        # Get TLG Files
        tlg_files = [tlg.attrib.get('A') for tlg in tsk.findall('TLG')]

        # Get Registered Values (DLV)
        # We look for DLV elements inside the main TIM tag of the task (totals)
        logged_values = []
        if tim is not None:
            for dlv in tim.findall('DLV'):
                ddi = dlv.attrib.get('A') # DDI ID
                raw_value = dlv.attrib.get('B') # Raw integer value
                
                # Lookup Danish name
                prop_name = ddi_definitions.get(ddi, f"DDI_{ddi}")
                
                logged_values.append(f"{prop_name}: {raw_value}")

        # Store in structure
        task_info = {
            'TaskID': tsk_id,
            'Machine': machine_name,
            'TLGs': tlg_files,
            'Properties': logged_values
        }
        
        # We assume one farm for the file, or use the one linked in TSK 'G' or 'D'
        # For this report we use the first found farm or "Ledreborg Gods"
        farm_name = list(farms.values())[0] if farms else "Unknown Farm"
        
        report_data[farm_name][year][field_name].append(task_info)

    # 5. Print Report
    print(f"--- ISOXML Content Report ---\n")
    for farm, years in report_data.items():
        print(f"FARM: {farm}")
        for year, fields_in_year in sorted(years.items()):
            print(f"\n  YEAR: {year}")
            for field, tasks in fields_in_year.items():
                print(f"    FIELD: {field}")
                for task in tasks:
                    print(f"      TASK: {task['TaskID']}")
                    print(f"        Machine: {task['Machine']}")
                    print(f"        TLG Files: {', '.join(task['TLGs'])}")
                    if task['Properties']:
                        print(f"        Registered Values (Totals):")
                        for prop in task['Properties']:
                            print(f"          - {prop}")
                    print("")

if __name__ == "__main__":
    # Replace with the actual path to your downloaded TASKDATA.XML
    file_path = PROJECT_ROOT / 'data' / 'taskdata' / 'TASKDATA.XML'
    try:
        parse_isoxml_taskdata(file_path)
    except Exception as e:
        print(f"Error parsing file: {e}")
# Out:
# --- ISOXML Content Report ---
#
# FARM: Ledreborg Gods
#
#   YEAR: 2022
#     FIELD: 016-2, Stendyssegård Højre
#       TASK: TSK14
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00010
#
#       TASK: TSK15
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 011-0, Akselbæk
#       TASK: TSK27
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00018
#
#       TASK: TSK28
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 035-0, Bispegård mark
#       TASK: TSK38
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00025
#
#       TASK: TSK39
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00026
#
#       TASK: TSK40
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 022-0, Lidia
#       TASK: TSK58
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00038
#
#       TASK: TSK59
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 013-0, Hulegaard b.
#       TASK: TSK87
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00057
#
#       TASK: TSK88
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 015-0, Hulemølle
#       TASK: TSK96
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00063
#
#       TASK: TSK97
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00064
#
#       TASK: TSK98
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 012-0, Hulegaardsmark
#       TASK: TSK130
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00085
#
#       TASK: TSK131
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 010-0, Møllemark
#       TASK: TSK182
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00119
#
#       TASK: TSK183
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 002-0, St.Amalienborg/Litgoth
#       TASK: TSK189
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00123
#
#       TASK: TSK190
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00124
#
#       TASK: TSK191
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00125
#
#       TASK: TSK192
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 016-1, Stendyssegård Venstr
#       TASK: TSK209
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00137
#
#       TASK: TSK210
#         Machine: Generic Implement
#         TLG Files:
#
#
#   YEAR: 2023
#     FIELD: 022-0, Lidia
#       TASK: TSK10
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00007
#
#       TASK: TSK11
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00008
#
#       TASK: TSK12
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00009
#
#       TASK: TSK13
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 011-0, Akselbæk
#       TASK: TSK16
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00011
#
#       TASK: TSK17
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00012
#
#       TASK: TSK18
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: B025-1, Brak - C/T Syd
#       TASK: TSK19
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00013
#
#       TASK: TSK20
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 023-2, Veronica 2
#       TASK: TSK21
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00014
#
#       TASK: TSK22
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00015
#
#       TASK: TSK23
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 015-0, Hulemølle
#       TASK: TSK32
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00021
#
#       TASK: TSK33
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00022
#
#       TASK: TSK34
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 014-0, Dellingemølle
#       TASK: TSK44
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00029
#
#       TASK: TSK45
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 023-0, Veronica 1
#       TASK: TSK46
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00030
#
#       TASK: TSK47
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00031
#
#       TASK: TSK48
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 016-2, Stendyssegård Højre
#       TASK: TSK55
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00036
#
#       TASK: TSK56
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00037
#
#       TASK: TSK57
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 035-0, Bispegård mark
#       TASK: TSK84
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00055
#
#       TASK: TSK85
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00056
#
#       TASK: TSK86
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 024-0, Silvia
#       TASK: TSK93
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00061
#
#       TASK: TSK94
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00062
#
#       TASK: TSK95
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 025-0, Camilla/Tatiana
#       TASK: TSK104
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00068
#
#       TASK: TSK105
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00069
#
#       TASK: TSK106
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 037-0, Bispegård øst
#       TASK: TSK107
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00070
#
#       TASK: TSK108
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 036-0, Bispegård vest
#       TASK: TSK109
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00071
#
#       TASK: TSK110
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00072
#
#       TASK: TSK111
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 021-0, Monica
#       TASK: TSK116
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00076
#
#       TASK: TSK117
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: M025-6
#       TASK: TSK128
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00084
#
#       TASK: TSK129
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 012-0, Hulegaardsmark
#       TASK: TSK135
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00088
#
#       TASK: TSK136
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00089
#
#       TASK: TSK137
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 016-0, Stendyssegård
#       TASK: TSK146
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00095
#
#       TASK: TSK147
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00096
#
#       TASK: TSK148
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 016-1, Stendyssegård Venstr
#       TASK: TSK149
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00097
#
#       TASK: TSK150
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00098
#
#       TASK: TSK151
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 013-0, Hulegaard b.
#       TASK: TSK164
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00107
#
#       TASK: TSK165
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00108
#
#       TASK: TSK166
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 002-0, St.Amalienborg/Litgoth
#       TASK: TSK167
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00109
#
#       TASK: TSK168
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00110
#
#       TASK: TSK169
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: B011-1, Brak - Akselbæk nord
#       TASK: TSK173
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00113
#
#       TASK: TSK174
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 010-0, Møllemark
#       TASK: TSK215
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00141
#
#       TASK: TSK216
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00142
#
#       TASK: TSK217
#         Machine: Generic Implement
#         TLG Files:
#
#
#   YEAR: 2024
#     FIELD: 021-0, Monica
#       TASK: TSK1
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00001
#
#       TASK: TSK2
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00002
#
#       TASK: TSK3
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 040-0, Holmegård syd
#       TASK: TSK24
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00016
#
#       TASK: TSK25
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00017
#
#       TASK: TSK26
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 012-0, Hulegaardsmark
#       TASK: TSK29
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00019
#
#       TASK: TSK30
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00020
#
#       TASK: TSK31
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 039-0, Holmegård nord
#       TASK: TSK49
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00032
#
#       TASK: TSK50
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00033
#
#       TASK: TSK51
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 022-0, Lidia
#       TASK: TSK52
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00034
#
#       TASK: TSK53
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00035
#
#       TASK: TSK54
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 023-0, Veronica 1
#       TASK: TSK60
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00039
#
#       TASK: TSK61
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00040
#
#       TASK: TSK62
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 010-0, Møllemark
#       TASK: TSK63
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00041
#
#       TASK: TSK64
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00042
#
#       TASK: TSK65
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 023-2, Veronica 2
#       TASK: TSK69
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00045
#
#       TASK: TSK70
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00046
#
#       TASK: TSK71
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 015-0, Hulemølle
#       TASK: TSK75
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00049
#
#       TASK: TSK76
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00050
#
#       TASK: TSK77
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 016-1, Stendyssegård Venstr
#       TASK: TSK89
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00058
#
#       TASK: TSK90
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00059
#
#       TASK: TSK91
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00060
#
#       TASK: TSK92
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 016-3, Stendysegård fold
#       TASK: TSK102
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00067
#
#       TASK: TSK103
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 035-0, Bispegård mark
#       TASK: TSK112
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00073
#
#       TASK: TSK113
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00074
#
#       TASK: TSK114
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00075
#
#       TASK: TSK115
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 036-0, Bispegård vest
#       TASK: TSK121
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00079
#
#       TASK: TSK122
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00080
#
#       TASK: TSK123
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00081
#
#       TASK: TSK124
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 002-0, St.Amalienborg
#       TASK: TSK132
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00086
#
#       TASK: TSK133
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00087
#
#       TASK: TSK134
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 024-0, Silvia
#       TASK: TSK141
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00092
#
#       TASK: TSK142
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 037-0, Bispegård øst
#       TASK: TSK175
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00114
#
#       TASK: TSK176
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00115
#
#       TASK: TSK177
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00116
#
#       TASK: TSK178
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 013-0, Hulegaard b.
#       TASK: TSK179
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00117
#
#       TASK: TSK180
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00118
#
#       TASK: TSK181
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 014-0, Dellingemølle
#       TASK: TSK184
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00120
#
#       TASK: TSK185
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 011-0, Akselbæk
#       TASK: TSK186
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00121
#
#       TASK: TSK187
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00122
#
#       TASK: TSK188
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 016-2, Stendyssegård Højre
#       TASK: TSK199
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00130
#
#       TASK: TSK200
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00131
#
#       TASK: TSK201
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00132
#
#       TASK: TSK202
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 025-0, Camilla/Tatiana
#       TASK: TSK203
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00133
#
#       TASK: TSK204
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00134
#
#       TASK: TSK205
#         Machine: Generic Implement
#         TLG Files:
#
#     FIELD: 016-0, Stendyssegård
#       TASK: TSK211
#         Machine: Nr: 220  C8600702
#         TLG Files: TLG00138
#
#       TASK: TSK212
#         Machine: Nr: 221  C8600703
#         TLG Files: TLG00139
#
#       TASK: TSK213
#         Machine: Nr: 224  C8600724
#         TLG Files: TLG00140
#
#       TASK: TSK214
#         Machine: Generic Implement
#         TLG Files:
#
#
#   YEAR: 2025
#     FIELD: Import
#       TASK: TSK4
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00003
#
#       TASK: TSK5
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00004
#
#       TASK: TSK6
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK7
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00005
#
#       TASK: TSK8
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00006
#
#       TASK: TSK9
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK35
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00023
#
#       TASK: TSK36
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00024
#
#       TASK: TSK37
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK41
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00027
#
#       TASK: TSK42
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00028
#
#       TASK: TSK43
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK66
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00043
#
#       TASK: TSK67
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00044
#
#       TASK: TSK68
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK72
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00047
#
#       TASK: TSK73
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00048
#
#       TASK: TSK74
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK78
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00051
#
#       TASK: TSK79
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00052
#
#       TASK: TSK80
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK81
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00053
#
#       TASK: TSK82
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00054
#
#       TASK: TSK83
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK99
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00065
#
#       TASK: TSK100
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00066
#
#       TASK: TSK101
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK118
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00077
#
#       TASK: TSK119
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00078
#
#       TASK: TSK120
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK125
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00082
#
#       TASK: TSK126
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00083
#
#       TASK: TSK127
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK138
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00090
#
#       TASK: TSK139
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00091
#
#       TASK: TSK140
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK143
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00093
#
#       TASK: TSK144
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00094
#
#       TASK: TSK145
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK152
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00099
#
#       TASK: TSK153
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00100
#
#       TASK: TSK154
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK155
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00101
#
#       TASK: TSK156
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00102
#
#       TASK: TSK157
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK158
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00103
#
#       TASK: TSK159
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00104
#
#       TASK: TSK160
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK161
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00105
#
#       TASK: TSK162
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00106
#
#       TASK: TSK163
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK170
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00111
#
#       TASK: TSK171
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00112
#
#       TASK: TSK172
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK193
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00126
#
#       TASK: TSK194
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00127
#
#       TASK: TSK195
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK196
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00128
#
#       TASK: TSK197
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00129
#
#       TASK: TSK198
#         Machine: Generic Implement
#         TLG Files:
#
#       TASK: TSK206
#         Machine: Nr: 222 C8600704
#         TLG Files: TLG00135
#
#       TASK: TSK207
#         Machine: Nr: 223 C8600722
#         TLG Files: TLG00136
#
#       TASK: TSK208
#         Machine: Generic Implement
#         TLG Files:
